# %%
tc_dir = "/data1/data/sar_jhb_dumps/tc"
dem_dir = "/data1/data/sar_jhb_dumps/mintpy"
dinsar_dir = "/data1/data/sar_jhb_dumps/dinsar"
mintpy_dir = "/data1/data/sar_jhb_dumps/mintpy/interferograms"
# !mkdir -p $dem_dir
# !mkdir -p $mintpy_dir

# %%
a = !ls $tc_dir/*.dim
print(a[0], a[1])
# Out:
# /data1/data/sar_jhb_dumps/tc/20171102_20180101.dim /data1/data/sar_jhb_dumps/tc/20171114_20180101.dim

# %%
a
# Out:
# ['/data1/data/sar_jhb_dumps/tc/20171102_20180101.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171114_20180101.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171114_20180113.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171126_20180101.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171126_20180113.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171126_20180125.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171208_20180101.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171208_20180113.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171208_20180125.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171208_20180206.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171220_20180101.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171220_20180113.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171220_20180125.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171220_20180206.dim',
#  '/data1/data/sar_jhb_dumps/tc/20171220_20180218.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180101_20180113.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180101_20180125.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180101_20180206.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180101_20180218.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180101_20180302.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180113_20180125.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180113_20180206.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180113_20180218.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180113_20180302.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180113_20180314.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180125_20180206.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180125_20180218.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180125_20180302.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180125_20180314.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180125_20180326.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180206_20180218.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180206_20180302.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180206_20180314.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180206_20180326.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180206_20180407.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180218_20180302.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180218_20180314.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180218_20180326.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180218_20180407.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180218_20180419.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180302_20180314.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180302_20180326.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180302_20180407.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180302_20180419.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180302_20180501.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180314_20180326.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180314_20180407.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180314_20180419.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180314_20180501.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180314_20180513.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180326_20180407.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180326_20180419.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180326_20180501.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180326_20180513.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180326_20180525.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180407_20180419.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180407_20180501.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180407_20180513.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180407_20180525.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180407_20180606.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180419_20180501.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180419_20180513.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180419_20180525.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180419_20180606.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180419_20180618.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180501_20180513.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180501_20180525.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180501_20180606.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180501_20180618.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180501_20180630.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180513_20180525.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180513_20180606.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180513_20180618.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180513_20180630.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180513_20180712.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180525_20180606.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180525_20180618.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180525_20180630.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180525_20180712.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180525_20180724.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180606_20180618.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180606_20180630.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180606_20180712.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180606_20180724.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180606_20180805.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180618_20180630.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180618_20180712.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180618_20180724.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180618_20180805.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180618_20180817.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180630_20180712.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180630_20180724.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180630_20180805.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180630_20180817.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180630_20180829.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180712_20180724.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180712_20180805.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180712_20180817.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180712_20180829.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180712_20180910.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180724_20180805.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180724_20180817.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180724_20180829.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180724_20180910.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180724_20180922.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180805_20180817.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180805_20180829.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180805_20180910.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180805_20180922.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180805_20181004.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180817_20180829.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180817_20180910.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180817_20180922.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180817_20181004.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180817_20181016.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180829_20180910.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180829_20180922.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180829_20181004.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180829_20181016.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180829_20181028.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180910_20180922.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180910_20181004.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180910_20181016.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180910_20181028.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180910_20181109.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180922_20181004.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180922_20181016.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180922_20181028.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180922_20181109.dim',
#  '/data1/data/sar_jhb_dumps/tc/20180922_20181121.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181004_20181016.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181004_20181028.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181004_20181109.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181004_20181121.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181004_20181203.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181016_20181028.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181016_20181109.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181016_20181121.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181016_20181203.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181016_20181215.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181028_20181109.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181028_20181121.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181028_20181203.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181028_20181215.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181028_20181227.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181109_20181121.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181109_20181203.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181109_20181215.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181109_20181227.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181109_20190108.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181121_20181203.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181121_20181215.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181121_20181227.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181121_20190108.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181121_20190120.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181203_20181215.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181203_20181227.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181203_20190108.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181203_20190120.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181203_20190201.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181215_20181227.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181215_20190108.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181215_20190120.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181215_20190201.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181215_20190213.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181227_20190108.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181227_20190120.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181227_20190201.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181227_20190213.dim',
#  '/data1/data/sar_jhb_dumps/tc/20181227_20190225.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190108_20190120.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190108_20190201.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190108_20190213.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190108_20190225.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190108_20190309.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190120_20190201.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190120_20190213.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190120_20190225.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190120_20190309.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190120_20190321.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190201_20190213.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190201_20190225.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190201_20190309.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190201_20190321.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190201_20190402.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190213_20190225.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190213_20190309.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190213_20190321.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190213_20190402.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190213_20190414.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190225_20190309.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190225_20190321.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190225_20190402.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190225_20190414.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190225_20190426.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190309_20190321.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190309_20190402.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190309_20190414.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190309_20190426.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190309_20190508.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190321_20190402.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190321_20190414.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190321_20190426.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190321_20190508.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190321_20190520.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190402_20190414.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190402_20190426.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190402_20190508.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190402_20190520.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190402_20190601.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190414_20190426.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190414_20190508.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190414_20190520.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190414_20190601.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190414_20190613.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190426_20190508.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190426_20190520.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190426_20190601.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190426_20190613.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190426_20190625.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190508_20190520.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190508_20190601.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190508_20190613.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190508_20190625.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190508_20190707.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190520_20190601.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190520_20190613.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190520_20190625.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190520_20190707.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190520_20190719.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190601_20190613.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190601_20190625.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190601_20190707.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190601_20190719.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190601_20190731.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190613_20190625.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190613_20190707.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190613_20190719.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190613_20190731.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190613_20190812.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190625_20190707.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190625_20190719.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190625_20190731.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190625_20190812.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190625_20190824.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190707_20190719.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190707_20190731.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190707_20190812.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190707_20190824.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190707_20190905.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190719_20190731.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190719_20190812.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190719_20190824.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190719_20190905.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190719_20190917.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190731_20190812.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190731_20190824.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190731_20190905.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190731_20190917.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190731_20190929.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190812_20190824.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190812_20190905.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190812_20190917.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190812_20190929.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190812_20191011.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190824_20190905.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190824_20190917.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190824_20190929.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190824_20191011.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190824_20191023.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190905_20190917.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190905_20190929.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190905_20191011.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190905_20191023.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190905_20191104.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190917_20190929.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190917_20191011.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190917_20191023.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190917_20191104.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190917_20191116.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190929_20191011.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190929_20191023.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190929_20191104.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190929_20191116.dim',
#  '/data1/data/sar_jhb_dumps/tc/20190929_20191128.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191011_20191023.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191011_20191104.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191011_20191116.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191011_20191128.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191011_20191210.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191023_20191104.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191023_20191116.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191023_20191128.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191023_20191210.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191023_20191222.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191104_20191116.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191104_20191128.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191104_20191210.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191104_20191222.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191104_20200103.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191116_20191128.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191116_20191210.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191116_20191222.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191116_20200103.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191116_20200115.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191128_20191210.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191128_20191222.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191128_20200103.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191128_20200115.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191128_20200127.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191210_20191222.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191210_20200103.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191210_20200115.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191210_20200127.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191210_20200208.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191222_20200103.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191222_20200115.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191222_20200127.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191222_20200208.dim',
#  '/data1/data/sar_jhb_dumps/tc/20191222_20200220.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200103_20200115.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200103_20200127.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200103_20200208.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200103_20200220.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200103_20200303.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200115_20200127.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200115_20200208.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200115_20200220.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200115_20200303.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200115_20200315.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200127_20200208.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200127_20200220.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200127_20200303.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200127_20200315.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200127_20200327.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200208_20200220.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200208_20200303.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200208_20200315.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200208_20200327.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200208_20200408.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200220_20200303.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200220_20200315.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200220_20200327.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200220_20200408.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200220_20200420.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200303_20200315.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200303_20200327.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200303_20200408.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200303_20200420.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200303_20200502.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200315_20200327.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200315_20200408.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200315_20200420.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200315_20200502.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200315_20200514.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200327_20200408.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200327_20200420.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200327_20200502.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200327_20200514.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200327_20200526.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200408_20200420.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200408_20200502.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200408_20200514.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200408_20200526.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200408_20200607.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200420_20200502.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200420_20200514.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200420_20200526.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200420_20200607.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200420_20200619.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200502_20200514.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200502_20200526.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200502_20200607.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200502_20200619.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200502_20200701.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200514_20200526.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200514_20200607.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200514_20200619.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200514_20200701.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200514_20200713.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200526_20200607.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200526_20200619.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200526_20200701.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200526_20200713.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200526_20200725.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200607_20200619.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200607_20200701.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200607_20200713.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200607_20200725.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200607_20200806.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200619_20200701.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200619_20200713.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200619_20200725.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200619_20200806.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200619_20200818.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200701_20200713.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200701_20200725.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200701_20200806.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200701_20200818.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200701_20200830.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200713_20200725.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200713_20200806.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200713_20200818.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200713_20200830.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200713_20200911.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200725_20200806.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200725_20200818.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200725_20200830.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200725_20200911.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200725_20200923.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200806_20200818.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200806_20200830.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200806_20200911.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200806_20200923.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200806_20201005.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200818_20200830.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200818_20200911.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200818_20200923.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200818_20201005.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200818_20201017.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200830_20200911.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200830_20200923.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200830_20201005.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200830_20201017.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200830_20201029.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200911_20200923.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200911_20201005.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200911_20201017.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200911_20201029.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200911_20201110.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200923_20201005.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200923_20201017.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200923_20201029.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200923_20201110.dim',
#  '/data1/data/sar_jhb_dumps/tc/20200923_20201122.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201005_20201017.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201005_20201029.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201005_20201110.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201005_20201122.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201005_20201204.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201017_20201029.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201017_20201110.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201017_20201122.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201017_20201204.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201017_20201216.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201029_20201110.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201029_20201122.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201029_20201204.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201029_20201216.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201029_20201228.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201110_20201122.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201110_20201204.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201110_20201216.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201110_20201228.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201122_20201204.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201122_20201216.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201122_20201228.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201204_20201216.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201204_20201228.dim',
#  '/data1/data/sar_jhb_dumps/tc/20201216_20201228.dim']

# %%
for i in range(len(a)):    
    source = a[i]
    print(source)
    source_name = a[i].split("/")[-1].split(".")[0]
    coh_path = !ls {tc_dir}/{source_name}.data/coh*.hdr
    coh_band = coh_path[0].split("/")[-1].split(".")[0]
    print(coh_band)
    # !mkdir $mintpy_dir/$source_name
    target_coh = "{}/{}/{}_coh_tc.dim".format(mintpy_dir,source_name,source_name)
    print(target_coh)
    unw_path = !ls {tc_dir}/{source_name}.data/Unw*.hdr
    unw_band = unw_path[0].split("/")[-1].split(".")[0]    
    print(unw_band)    
    target_unw = "{}/{}/{}_unw_tc.dim".format(mintpy_dir,source_name,source_name)    
    c = !ls $mintpy_dir/$source_name | grep *.dim
    print(c)
    if len(c) == 0:
        # !gpt graph/mintpy_subset.xml -Psource=$source -Pcoh_band=$coh_band -Punw_band=$unw_band -Ptarget_unw=$target_unw -Ptarget_coh=$target_coh
# Out:
# /data1/data/sar_jhb_dumps/tc/20171102_20180101.dim
# coh_VV_02Nov2017_01Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171102_20180101/20171102_20180101_coh_tc.dim
# Unw_Phase_ifg_02Nov2017_01Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171114_20180101.dim
# coh_VV_14Nov2017_01Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171114_20180101/20171114_20180101_coh_tc.dim
# Unw_Phase_ifg_14Nov2017_01Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171114_20180113.dim
# coh_VV_14Nov2017_13Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171114_20180113/20171114_20180113_coh_tc.dim
# Unw_Phase_ifg_14Nov2017_13Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171126_20180101.dim
# coh_VV_26Nov2017_01Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171126_20180101/20171126_20180101_coh_tc.dim
# Unw_Phase_ifg_26Nov2017_01Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171126_20180113.dim
# coh_VV_26Nov2017_13Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171126_20180113/20171126_20180113_coh_tc.dim
# Unw_Phase_ifg_26Nov2017_13Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171126_20180125.dim
# coh_VV_26Nov2017_25Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171126_20180125/20171126_20180125_coh_tc.dim
# Unw_Phase_ifg_26Nov2017_25Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171208_20180101.dim
# coh_VV_08Dec2017_01Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171208_20180101/20171208_20180101_coh_tc.dim
# Unw_Phase_ifg_08Dec2017_01Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171208_20180113.dim
# coh_VV_08Dec2017_13Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171208_20180113/20171208_20180113_coh_tc.dim
# Unw_Phase_ifg_08Dec2017_13Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171208_20180125.dim
# coh_VV_08Dec2017_25Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171208_20180125/20171208_20180125_coh_tc.dim
# Unw_Phase_ifg_08Dec2017_25Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171208_20180206.dim
# coh_VV_08Dec2017_06Feb2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171208_20180206/20171208_20180206_coh_tc.dim
# Unw_Phase_ifg_08Dec2017_06Feb2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171220_20180101.dim
# coh_VV_20Dec2017_01Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171220_20180101/20171220_20180101_coh_tc.dim
# Unw_Phase_ifg_20Dec2017_01Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171220_20180113.dim
# coh_VV_20Dec2017_13Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171220_20180113/20171220_20180113_coh_tc.dim
# Unw_Phase_ifg_20Dec2017_13Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171220_20180125.dim
# coh_VV_20Dec2017_25Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171220_20180125/20171220_20180125_coh_tc.dim
# Unw_Phase_ifg_20Dec2017_25Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171220_20180206.dim
# coh_VV_20Dec2017_06Feb2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171220_20180206/20171220_20180206_coh_tc.dim
# Unw_Phase_ifg_20Dec2017_06Feb2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20171220_20180218.dim
# coh_VV_20Dec2017_18Feb2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20171220_20180218/20171220_20180218_coh_tc.dim
# Unw_Phase_ifg_20Dec2017_18Feb2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180101_20180113.dim
# coh_VV_01Jan2018_13Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180101_20180113/20180101_20180113_coh_tc.dim
# Unw_Phase_ifg_01Jan2018_13Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180101_20180125.dim
# coh_VV_01Jan2018_25Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180101_20180125/20180101_20180125_coh_tc.dim
# Unw_Phase_ifg_01Jan2018_25Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180101_20180206.dim
# coh_VV_01Jan2018_06Feb2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180101_20180206/20180101_20180206_coh_tc.dim
# Unw_Phase_ifg_01Jan2018_06Feb2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180101_20180218.dim
# coh_VV_01Jan2018_18Feb2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180101_20180218/20180101_20180218_coh_tc.dim
# Unw_Phase_ifg_01Jan2018_18Feb2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180101_20180302.dim
# coh_VV_01Jan2018_02Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180101_20180302/20180101_20180302_coh_tc.dim
# Unw_Phase_ifg_01Jan2018_02Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180113_20180125.dim
# coh_VV_13Jan2018_25Jan2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180113_20180125/20180113_20180125_coh_tc.dim
# Unw_Phase_ifg_13Jan2018_25Jan2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180113_20180206.dim
# coh_VV_13Jan2018_06Feb2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180113_20180206/20180113_20180206_coh_tc.dim
# Unw_Phase_ifg_13Jan2018_06Feb2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180113_20180218.dim
# coh_VV_13Jan2018_18Feb2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180113_20180218/20180113_20180218_coh_tc.dim
# Unw_Phase_ifg_13Jan2018_18Feb2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180113_20180302.dim
# coh_VV_13Jan2018_02Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180113_20180302/20180113_20180302_coh_tc.dim
# Unw_Phase_ifg_13Jan2018_02Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180113_20180314.dim
# coh_VV_13Jan2018_14Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180113_20180314/20180113_20180314_coh_tc.dim
# Unw_Phase_ifg_13Jan2018_14Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180125_20180206.dim
# coh_VV_25Jan2018_06Feb2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180125_20180206/20180125_20180206_coh_tc.dim
# Unw_Phase_ifg_25Jan2018_06Feb2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180125_20180218.dim
# coh_VV_25Jan2018_18Feb2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180125_20180218/20180125_20180218_coh_tc.dim
# Unw_Phase_ifg_25Jan2018_18Feb2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180125_20180302.dim
# coh_VV_25Jan2018_02Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180125_20180302/20180125_20180302_coh_tc.dim
# Unw_Phase_ifg_25Jan2018_02Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180125_20180314.dim
# coh_VV_25Jan2018_14Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180125_20180314/20180125_20180314_coh_tc.dim
# Unw_Phase_ifg_25Jan2018_14Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180125_20180326.dim
# coh_VV_25Jan2018_26Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180125_20180326/20180125_20180326_coh_tc.dim
# Unw_Phase_ifg_25Jan2018_26Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180206_20180218.dim
# coh_VV_06Feb2018_18Feb2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180206_20180218/20180206_20180218_coh_tc.dim
# Unw_Phase_ifg_06Feb2018_18Feb2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180206_20180302.dim
# coh_VV_06Feb2018_02Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180206_20180302/20180206_20180302_coh_tc.dim
# Unw_Phase_ifg_06Feb2018_02Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180206_20180314.dim
# coh_VV_06Feb2018_14Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180206_20180314/20180206_20180314_coh_tc.dim
# Unw_Phase_ifg_06Feb2018_14Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180206_20180326.dim
# coh_VV_06Feb2018_26Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180206_20180326/20180206_20180326_coh_tc.dim
# Unw_Phase_ifg_06Feb2018_26Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180206_20180407.dim
# coh_VV_06Feb2018_07Apr2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180206_20180407/20180206_20180407_coh_tc.dim
# Unw_Phase_ifg_06Feb2018_07Apr2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180218_20180302.dim
# coh_VV_18Feb2018_02Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180218_20180302/20180218_20180302_coh_tc.dim
# Unw_Phase_ifg_18Feb2018_02Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180218_20180314.dim
# coh_VV_18Feb2018_14Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180218_20180314/20180218_20180314_coh_tc.dim
# Unw_Phase_ifg_18Feb2018_14Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180218_20180326.dim
# coh_VV_18Feb2018_26Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180218_20180326/20180218_20180326_coh_tc.dim
# Unw_Phase_ifg_18Feb2018_26Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180218_20180407.dim
# coh_VV_18Feb2018_07Apr2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180218_20180407/20180218_20180407_coh_tc.dim
# Unw_Phase_ifg_18Feb2018_07Apr2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180218_20180419.dim
# coh_VV_18Feb2018_19Apr2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180218_20180419/20180218_20180419_coh_tc.dim
# Unw_Phase_ifg_18Feb2018_19Apr2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180302_20180314.dim
# coh_VV_02Mar2018_14Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180302_20180314/20180302_20180314_coh_tc.dim
# Unw_Phase_ifg_02Mar2018_14Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180302_20180326.dim
# coh_VV_02Mar2018_26Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180302_20180326/20180302_20180326_coh_tc.dim
# Unw_Phase_ifg_02Mar2018_26Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180302_20180407.dim
# coh_VV_02Mar2018_07Apr2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180302_20180407/20180302_20180407_coh_tc.dim
# Unw_Phase_ifg_02Mar2018_07Apr2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180302_20180419.dim
# coh_VV_02Mar2018_19Apr2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180302_20180419/20180302_20180419_coh_tc.dim
# Unw_Phase_ifg_02Mar2018_19Apr2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180302_20180501.dim
# coh_VV_02Mar2018_01May2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180302_20180501/20180302_20180501_coh_tc.dim
# Unw_Phase_ifg_02Mar2018_01May2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180314_20180326.dim
# coh_VV_14Mar2018_26Mar2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180314_20180326/20180314_20180326_coh_tc.dim
# Unw_Phase_ifg_14Mar2018_26Mar2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180314_20180407.dim
# coh_VV_14Mar2018_07Apr2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180314_20180407/20180314_20180407_coh_tc.dim
# Unw_Phase_ifg_14Mar2018_07Apr2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180314_20180419.dim
# coh_VV_14Mar2018_19Apr2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180314_20180419/20180314_20180419_coh_tc.dim
# Unw_Phase_ifg_14Mar2018_19Apr2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180314_20180501.dim
# coh_VV_14Mar2018_01May2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180314_20180501/20180314_20180501_coh_tc.dim
# Unw_Phase_ifg_14Mar2018_01May2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180314_20180513.dim
# coh_VV_14Mar2018_13May2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180314_20180513/20180314_20180513_coh_tc.dim
# Unw_Phase_ifg_14Mar2018_13May2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180326_20180407.dim
# coh_VV_26Mar2018_07Apr2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180326_20180407/20180326_20180407_coh_tc.dim
# Unw_Phase_ifg_26Mar2018_07Apr2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180326_20180419.dim
# coh_VV_26Mar2018_19Apr2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180326_20180419/20180326_20180419_coh_tc.dim
# Unw_Phase_ifg_26Mar2018_19Apr2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180326_20180501.dim
# coh_VV_26Mar2018_01May2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180326_20180501/20180326_20180501_coh_tc.dim
# Unw_Phase_ifg_26Mar2018_01May2018_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20180326_20180513.dim
# coh_VV_26Mar2018_13May2018
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20180326_20180513/20180326_20180513_coh_tc.dim
# ...
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201017_20201204.dim
# coh_VV_17Oct2020_04Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201017_20201204/20201017_20201204_coh_tc.dim
# Unw_Phase_ifg_17Oct2020_04Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201017_20201216.dim
# coh_VV_17Oct2020_16Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201017_20201216/20201017_20201216_coh_tc.dim
# Unw_Phase_ifg_17Oct2020_16Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201029_20201110.dim
# coh_VV_29Oct2020_10Nov2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201029_20201110/20201029_20201110_coh_tc.dim
# Unw_Phase_ifg_29Oct2020_10Nov2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201029_20201122.dim
# coh_VV_29Oct2020_22Nov2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201029_20201122/20201029_20201122_coh_tc.dim
# Unw_Phase_ifg_29Oct2020_22Nov2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201029_20201204.dim
# coh_VV_29Oct2020_04Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201029_20201204/20201029_20201204_coh_tc.dim
# Unw_Phase_ifg_29Oct2020_04Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201029_20201216.dim
# coh_VV_29Oct2020_16Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201029_20201216/20201029_20201216_coh_tc.dim
# Unw_Phase_ifg_29Oct2020_16Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201029_20201228.dim
# coh_VV_29Oct2020_28Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201029_20201228/20201029_20201228_coh_tc.dim
# Unw_Phase_ifg_29Oct2020_28Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201110_20201122.dim
# coh_VV_10Nov2020_22Nov2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201110_20201122/20201110_20201122_coh_tc.dim
# Unw_Phase_ifg_10Nov2020_22Nov2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201110_20201204.dim
# coh_VV_10Nov2020_04Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201110_20201204/20201110_20201204_coh_tc.dim
# Unw_Phase_ifg_10Nov2020_04Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201110_20201216.dim
# coh_VV_10Nov2020_16Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201110_20201216/20201110_20201216_coh_tc.dim
# Unw_Phase_ifg_10Nov2020_16Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201110_20201228.dim
# coh_VV_10Nov2020_28Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201110_20201228/20201110_20201228_coh_tc.dim
# Unw_Phase_ifg_10Nov2020_28Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201122_20201204.dim
# coh_VV_22Nov2020_04Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201122_20201204/20201122_20201204_coh_tc.dim
# Unw_Phase_ifg_22Nov2020_04Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201122_20201216.dim
# coh_VV_22Nov2020_16Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201122_20201216/20201122_20201216_coh_tc.dim
# Unw_Phase_ifg_22Nov2020_16Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201122_20201228.dim
# coh_VV_22Nov2020_28Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201122_20201228/20201122_20201228_coh_tc.dim
# Unw_Phase_ifg_22Nov2020_28Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201204_20201216.dim
# coh_VV_04Dec2020_16Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201204_20201216/20201204_20201216_coh_tc.dim
# Unw_Phase_ifg_04Dec2020_16Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201204_20201228.dim
# coh_VV_04Dec2020_28Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201204_20201228/20201204_20201228_coh_tc.dim
# Unw_Phase_ifg_04Dec2020_28Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.
# /data1/data/sar_jhb_dumps/tc/20201216_20201228.dim
# coh_VV_16Dec2020_28Dec2020
# /data1/data/sar_jhb_dumps/mintpy/interferograms/20201216_20201228/20201216_20201228_coh_tc.dim
# Unw_Phase_ifg_16Dec2020_28Dec2020_VV
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# ....10%....20%....30%....40%....50%....60%....70%....80%....90% done.

# %%
# !gpt -h
# Out:
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Usage:
#   gpt <op>|<graph-file> [options] [<source-file-1> <source-file-2> ...]
#
# Description:
#   This tool is used to execute SNAP raster data operators in batch-mode. The
#   operators can be used stand-alone or combined as a directed acyclic graph
#   (DAG). Processing graphs are represented using XML. More info about
#   processing graphs, the operator API, and the graph XML format can be found
#   in the SNAP documentation.
#
# Arguments:
#   <op>               Name of an operator. See below for the list of <op>s.
#   <graph-file>       Operator graph file (XML format).
#   <source-file-i>    The <i>th source product file. The actual number of source
#                      file arguments is specified by <op>. May be optional for
#                      operators which use the -S option.
#
# Options:
#   -h                 Displays command usage. If <op> is given, the specific
#                      operator usage is displayed.
#   -e                 Displays more detailed error messages. Displays a stack
#                      trace, if an exception occurs.
#   -t <file>          The target file. Default value is 'target.dim'.
#   -f <format>        Output file format, e.g. 'GeoTIFF', 'HDF5',
#                      'BEAM-DIMAP'. If not specified, format will be derived
#                      from the target filename extension, if any, otherwise the
#                      default format is 'BEAM-DIMAP'. Ony used, if the graph
#                      in <graph-file> does not specify its own 'Write'
#                      operator.
#   -p <file>          A (Java Properties) file containing processing parameters
#                      in the form <name>=<value> or a XML file containing a
#                      parameter DOM for the operator. Entries in this file are
#                      overwritten by the -P<name>=<value> command-line option
#                      (see below). The following variables are substituted in
#                      the parameters file:
#                          ${system.<java-sys-property>}
#                          ${operatorName} (given by the <op> argument)
#                          ${graphFile} (given by the <graph-file> argument)
#                          ${targetFile} (pull path given by the -t option)
#                          ${targetDir} (derived from -t option)
#                          ${targetName} (derived from -t option)
#                          ${targetBaseName} (derived from -t option)
#                          ${targetFormat} (given by the -f option)
#   -c <cache-size>    Sets the tile cache size in bytes. Value can be suffixed
#                      with 'K', 'M' and 'G'. Must be less than maximum
#                      available heap space. If equal to or less than zero, tile
#                      caching will be completely disabled. The default tile
#                      cache size is '1,073,741,824M'.
#   -q <parallelism>   Sets the maximum parallelism used for the computation,
#                      i.e. the maximum number of parallel (native) threads.
#                      The default parallelism is '12'.
#   -x                 Clears the internal tile cache after writing a complete
#                      row of tiles to the target product file. This option may
#                      be useful if you run into memory problems.
#   -S<source>=<file>  Defines a source product. <source> is specified by the
#                      operator or the graph. In an XML graph, all occurrences of
#                      ${<source>} will be replaced with references to a source
#                      product located at <file>.
#   -P<name>=<value>   Defines a processing parameter, <name> is specific for the
#                      used operator or graph. In an XML graph, all occurrences
#                      of ${<name>} will be replaced with <value>. Overwrites
#                      parameter values specified by the '-p' option.
#   -D<name>=<value>   Defines a system property for this invocation.
#   -v <dir>           A directory containing any number of Velocity templates.
#                      Each template generates a text output file along with the
#                      target product. This feature has been added to support a
#                      flexible generation of metadata files.
#                      See http://velocity.apache.org/ and option -m.
#   -m <file>          A (Java Properties) file containing (constant) metadata
#                      in the form <name>=<value> or any XML file. Its primary
#                      usage is to provide an additional context to be used
#                      from within the Velocity templates. See option -v.
#   --diag             Displays version and diagnostic information.
# Operators:
#   Aatsr.SST                            Computes sea surface temperature (SST) from (A)ATSR products.
#   AATSR.Ungrid                         Ungrids (A)ATSR L1B products and extracts geolocation and pixel field of view data.
#   AdaptiveThresholding                 Detect ships using Constant False Alarm Rate detector.
#   AddElevation                         Creates a DEM band
#   AddLandCover                         Creates a land cover band
#   ALOS-Deskewing                       Deskewing ALOS product
#   Apply-Orbit-File                     Apply orbit file
#   Arc.SST                              Computes sea surface temperature (SST) from (A)ATSR and SLSTR products.
#   ArviOp                               Atmospherically Resistant Vegetation Index belongs to a family of indices with built-in atmospheric corrections.
#   Azimuth-Shift-Estimation-ESD         Estimate azimuth offset for the whole image
#   AzimuthFilter                        Azimuth Filter
#   Back-Geocoding                       Bursts co-registration using orbit and DEM
#   BandMaths                            Create a product with one or more bands using mathematical expressions.
#   BandMerge                            Allows copying raster data from any number of source products to a specified 'master' product.
#   BandsDifferenceOp                    No description available.
#   BandSelect                           Creates a new product with only selected bands
#   BandsExtractorOp                     Creates a new product out of the source product containing only the indexes bands given
#   Bi2Op                                The Brightness index represents the average of the brightness of a satellite image.
#                                        This index is sensitive to the brightness of soils which is highly correlated with the humidity and the presence of salts in surface
#   Binning                              Performs spatial and temporal aggregation of pixel values into cells ('bins') of a planetary grid
#   BiOp                                 The Brightness index represents the average of the brightness of a satellite image.
#   Biophysical10mOp                     The 'Biophysical Processor' operator retrieves LAI from atmospherically corrected Sentinel-2 products
#   BiophysicalLandsat8Op                The 'Biophysical Processor' operator retrieves LAI from atmospherically corrected Landsat8 products
#   BiophysicalOp                        The 'Biophysical Processor' operator retrieves LAI from atmospherically corrected Sentinel-2 products
#   c2rcc.landsat8                       Performs atmospheric correction and IOP retrieval with uncertainties on Landsat-8 L1 data products.
#   c2rcc.meris                          Performs atmospheric correction and IOP retrieval with uncertainties on MERIS L1b data products.
#   c2rcc.meris4                         Performs atmospheric correction and IOP retrieval with uncertainties on MERIS L1b data products from the 4th reprocessing.
#   c2rcc.modis                          Performs atmospheric correction and IOP retrieval on MODIS L1C_LAC data products.
#   c2rcc.msi                            Performs atmospheric correction and IOP retrieval with uncertainties on Sentinel-2 MSI L1C data products.
#   c2rcc.olci                           Performs atmospheric correction and IOP retrieval with uncertainties on SENTINEL-3 OLCI L1B data products.
#   c2rcc.seawifs                        Performs atmospheric correction and IOP retrieval on SeaWifs L1C data products.
#   c2rcc.viirs                          Performs atmospheric correction and IOP retrieval on Viirs L1C data products.
#   Calibration                          Calibration of products
#   Change-Detection                     Change Detection.
#   CiOp                                 Colour Index  was developed to differentiate soils in the field.
#                                        In most cases the CI gives complementary information with the BI and the NDVI.
#                                         Used for diachronic analyses, they help for a better understanding of the evolution of soil surfaces.
#   CloudProb                            Applies a clear sky conservative cloud detection algorithm.
#   Coherence                            Estimate coherence from stack of coregistered images
#   Collocate                            Collocates two products based on their geo-codings.
#   Compute-Slope-Aspect                 Compute Slope and Aspect from DEM
#   Convert-Datatype                     Convert product data type
#   CoregistrationOp                     Coregisters two rasters, not considering their location
#   CP-Decomposition                     Perform Compact Polarimetric decomposition of a given product
#   CP-Simulation                        Simulation of Compact Pol data from Quad Pol data
#   CP-Stokes-Parameters                 Generates compact polarimetric Stokes child parameters
#   CreateStack                          Collocates two or more products based on their geo-codings.
#   Cross-Channel-SNR-Correction         Compute general polarimetric parameters
#   Cross-Correlation                    Automatic Selection of Ground Control Points
#   CrossResampling                      Estimate Resampling Polynomial using SAR Image Geometry, and Resample Input Images
#   DeburstWSS                           Debursts an ASAR WSS product
#   DecisionTree                         Perform decision tree classification
#   DEM-Assisted-Coregistration          Orbit and DEM based co-registration
#   Demodulate                           Demodulation and deramping of SLC data
#   Double-Difference-Interferogram      Compute double difference interferogram
#   DviOp                                Difference Vegetation Index retrieves the Isovegetation lines parallel to soil line
#   EAP-Phase-Correction                 EAP Phase Correction
#   Ellipsoid-Correction-GG              GG method for orthorectification
#   Ellipsoid-Correction-RD              Ellipsoid correction with RD method and average scene height
#   EMClusterAnalysis                    Performs an expectation-maximization (EM) cluster analysis.
#   Enhanced-Spectral-Diversity          Estimate constant range and azimuth offsets for a stack of images
#   Fill-DEM-Hole                        Fill holes in given DEM product file.
#   Find-Image-Pair                      DB query to find matching image pair
#   FlhMci                               Computes fluorescence line height (FLH) or maximum chlorophyll index (MCI).
#   Flip                                 flips a product horizontal/vertical
#   ForestCoverChangeOp                  Creates forest change masks out of two source products
#   FUB.Water                            FUB/WeW WATER Processor to retrieve case II water properties and atmospheric properties
#   FuClassification                     Colour classification based on the discrete Forel-Ule scale.
#   GemiOp                               This retrieves the Global Environmental Monitoring Index (GEMI).
#   GenericRegionMergingOp               The 'Generic Region Merging' operator computes the distinct regions from a product
#   GLCM                                 Extract Texture Features
#   GndviOp                              Green Normalized Difference Vegetation Index
#   GoldsteinPhaseFiltering              Phase Filtering
#   GRD-Post                             Applies GRD post-processing
#   IEM-Hybrid-Inversion                 Performs IEM inversion using Hybrid approach
#   IEM-Multi-Angle-Inversion            Performs IEM inversion using Multi-angle approach
#   IEM-Multi-Pol-Inversion              Performs IEM inversion using Multi-polarization approach
#   Image-Filter                         Common Image Processing Filters
#   Import-Vector                        Imports a shape file into a product
#   IntegerInterferogram                 Create integer interferogram
#   Interferogram                        Compute interferograms from stack of coregistered S-1 images
#   IpviOp                               Infrared Percentage Vegetation Index retrieves the Isovegetation lines converge at origin
#   IreciOp                              Inverted red-edge chlorophyll index
#   KDTree-KNN-Classifier                KDTree KNN classifier
#   KMeansClusterAnalysis                Performs a K-Means cluster analysis.
#   KNN-Classifier                       K-Nearest Neighbour classifier
#   Land-Cover-Mask                      Perform decision tree classification
#   Land-Sea-Mask                        Creates a bitmask defining land vs ocean.
#   LandWaterMask                        Operator creating a target product with a single band containing a land/water-mask.
#   LinearToFromdB                       Converts bands to/from dB
#   Maximum-Likelihood-Classifier        Maximum Likelihood classifier
#   McariOp                              Modified Chlorophyll Absorption Ratio Index, developed to be responsive to chlorophyll variation
#   Mci.s2                               Computes maximum chlorophyll index (MCI) for Sentinel-2 MSI.
#   Merge                                Allows merging of several source products by using specified 'master' as reference product.
#   Meris.CorrectRadiometry              Performs radiometric corrections on MERIS L1b data products.
#   Meris.N1Patcher                      Copies an existing N1 file and replaces the data for the radiance bands
#   Minimum-Distance-Classifier          Minimum Distance classifier
#   MndwiOp                              Modified Normalized Difference Water Index, allowing for the measurement of surface water extent
#   Mosaic                               Creates a mosaic out of a set of source products.
#   MphChl                               This operator computes maximum peak height of chlorophyll (MPH/CHL).
#   Msavi2Op                             This retrieves the second Modified Soil Adjusted Vegetation Index (MSAVI2).
#   MsaviOp                              This retrieves the Modified Soil Adjusted Vegetation Index (MSAVI).
#   MtciOp                               The Meris Terrestrial Chlorophyll Index,  aims at estimating the Red Edge Position (REP).
#                                        This is the maximum slant point in the red and near-infrared region of the vegetal spectral reflectance.
#                                        It is useful for observing the chlorophyll contents, vegetation senescence, and stress for water and nutritional deficiencies, but it is less suitable for land classification
#   Multi-size Mosaic                    Creates a multi-size mosaic out of a set of source products.
#   Multi-Temporal-Speckle-Filter        Speckle Reduction using Multitemporal Filtering
#   Multilook                            Averages the power across a number of lines in both the azimuth and range directions
#   MultiMasterStackGenerator            Generates a set of master-slave pairs from a coregistered stack for use in SBAS processing
#   Ndi45Op                              Normalized Difference Index using bands 4 and 5
#   NdpiOp                               The normalized differential pond index, combines the short-wave infrared band-I and the green band
#   NdtiOp                               Normalized difference turbidity index, allowing for the measurement of water turbidity
#   NdviOp                               The retrieves the Normalized Difference Vegetation Index (NDVI).
#   Ndwi2Op                              The Normalized Difference Water Index, allowing for the measurement of surface water extent
#   NdwiOp                               The Normalized Difference Water Index was developed for the extraction of water features
#   Object-Discrimination                Remove false alarms from the detected objects.
#   Offset-Tracking                      Create velocity vectors from offset tracking
#   Oil-Spill-Clustering                 Remove small clusters from detected area.
#   Oil-Spill-Detection                  Detect oil spill.
#   OlciO2aHarmonisation                 Performs O2A band harmonisation on OLCI L1b product.
#   Orientation-Angle-Correction         Perform polarization orientation angle correction for given coherency matrix
#   Oversample                           Oversample the datset
#   OWTClassification                    Performs an optical water type classification based on atmospherically corrected reflectances.
#   PCA                                  Performs a Principal Component Analysis.
#   PduStitching                         Stitches multiple SLSTR L1B product dissemination units (PDUs) of the same orbit to a single product.
#   PhaseToDisplacement                  Phase To Displacement Conversion along LOS
#   PhaseToElevation                     DEM Generation
#   PhaseToHeight                        Phase to Height conversion
#   PixEx                                Extracts pixels from given locations and source products.
#   Polarimetric-Classification          Perform Polarimetric classification of a given product
#   Polarimetric-Decomposition           Perform Polarimetric decomposition of a given product
#   Polarimetric-Matrices                Generates covariance or coherency matrix for given product
#   Polarimetric-Parameters              Compute general polarimetric parameters
#   Polarimetric-Speckle-Filter          Polarimetric Speckle Reduction
#   PpeFiltering                         Performs Prompt Particle Event (PPE) filtering on OLCI L1B
#   Principle-Components                 Principle Component Analysis
#   ProductSet-Reader                    Adds a list of sources
#   PssraOp                              Pigment Specific Simple Ratio, chlorophyll index
#   PviOp                                Perpendicular Vegetation Index retrieves the Isovegetation lines parallel to soil line. Soil line has an arbitrary slope and passes through origin
#   Rad2Refl                             Provides conversion from radiances to reflectances or backwards.
#   Random-Forest-Classifier             Random Forest based classifier
#   RangeFilter                          Range Filter
#   RayleighCorrection                   Performs radiometric corrections on OLCI, MERIS L1B and S2 MSI L1C data products.
#   Read                                 Reads a data product from a given file location.
#   ReflectanceToRadianceOp              The 'Reflectance To Radiance Processor' operator retrieves the radiance from reflectance using Sentinel-2 products
#   ReipOp                               The red edge inflection point index
#   Remodulate                           Remodulation and reramping of SLC data
#   RemoteExecutionOp                    The Remote Execution Processor executes on the remote machines a slave graph and then on the host machine it executes a master graph using the products created by the remote machines.
#   Remove-GRD-Border-Noise              Mask no-value pixels for GRD product
#   RemoveAntennaPattern                 Remove Antenna Pattern
#   ReplaceMetadata                      Replace the metadata of the first product with that of the second
#   Reproject                            Reprojection of a source product to a target Coordinate Reference System.
#   Resample                             Resampling of a multi-size source product to a single-size target product.
#   RiOp                                 The Redness Index was developed to identify soil colour variations.
#   RviOp                                Ratio Vegetation Index retrieves the Isovegetation lines converge at origin
#   S2repOp                              Sentinel-2 red-edge position index
#   S2Resampling                         Specific S2 resample algorithm
#   SAR-Mosaic                           Mosaics two or more products based on their geo-codings.
#   SAR-Simulation                       Rigorous SAR Simulation
#   SARSim-Terrain-Correction            Orthorectification with SAR simulation
#   SaviOp                               This retrieves the Soil-Adjusted Vegetation Index (SAVI).
#   SetNoDataValue                       Set NoDataValueUsed flag and NoDataValue for all bands
#   SliceAssembly                        Merges Sentinel-1 slice products
#   SM-Dielectric-Modeling               Performs SM inversion using dielectric model
#   SmacOp                               Applies the Simplified Method for Atmospheric Corrections of Envisat MERIS/(A)ATSR measurements.
#   SnaphuExport                         Export data and prepare conf file for SNAPHU processing
#   SnaphuImport                         Ingest SNAPHU results into InSAR product.
#   Speckle-Divergence                   Detect urban area.
#   Speckle-Filter                       Speckle Reduction
#   SpectralAngleMapperOp                Classifies a product using the spectral angle mapper algorithm
#   SRGR                                 Converts Slant Range to Ground Range
#   Stack-Averaging                      Averaging multi-temporal images
#   Stack-Split                          Writes all bands to files.
#   StampsExport                         Export data for StaMPS processing
#   StatisticsOp                         Computes statistics for an arbitrary number of source products.
#   SubGraph                             Encapsulates a graph within a graph.
#   Subset                               Create a spatial and/or spectral subset of a data product.
#   Supervised-Wishart-Classification    Perform supervised Wishart classification
#   TemporalPercentile                   Computes percentiles over a given time period.
#   Terrain-Correction                   RD method for orthorectification
#   Terrain-Flattening                   Terrain Flattening
#   Terrain-Mask                         Terrain Mask Generation
#   ThermalNoiseRemoval                  Removes thermal noise from products
#   Three-passDInSAR                     Differential Interferometry
#   TileCache                            Experimental Operator which provides a dedicated cache for its source product.
#                                        A guide on how this operator is used is provided at https://senbox.atlassian.net/wiki/x/VQCTLw.
#   TileWriter                           Writes a data product to a tiles.
#   TndviOp                              Transformed Normalized Difference Vegetation Index retrieves the Isovegetation lines parallel to soil line
#   ToolAdapterOp                        Tool Adapter Operator
#   TopoPhaseRemoval                     Compute and subtract TOPO phase
#   TOPSAR-Deburst                       Debursts a Sentinel-1 TOPSAR product
#   TOPSAR-DerampDemod                   Bursts co-registration using orbit and DEM
#   TOPSAR-Merge                         Merge subswaths of a Sentinel-1 TOPSAR product
#   TOPSAR-Split                         Creates a new product with only the selected subswath
#   TsaviOp                              This retrieves the Transformed Soil Adjusted Vegetation Index (TSAVI).
#   Undersample                          Undersample the datset
#   Unmix                                Performs a linear spectral unmixing.
#   Update-Geo-Reference                 Update Geo Reference
#   Warp                                 Create Warp Function And Get Co-registrated Images
#   WdviOp                               Weighted Difference Vegetation Index retrieves the Isovegetation lines parallel to soil line. Soil line has an arbitrary slope and passes through origin
#   Wind-Field-Estimation                Estimate wind speed and direction
#   Write                                Writes a data product to a file.

# %%
b = !ls $dinsar_dir/*.dim
b.sort()
# Out:
# ['/data1/data/sar_jhb_dumps/dinsar/20171102_20180101.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171114_20180101.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171114_20180113.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171126_20180101.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171126_20180113.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171126_20180125.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171208_20180101.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171208_20180113.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171208_20180125.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171208_20180206.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171220_20180101.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171220_20180113.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171220_20180125.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171220_20180206.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20171220_20180218.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180101_20180113.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180101_20180125.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180101_20180206.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180101_20180218.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180101_20180302.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180113_20180125.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180113_20180206.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180113_20180218.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180113_20180302.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180113_20180314.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180125_20180206.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180125_20180218.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180125_20180302.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180125_20180314.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180125_20180326.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180206_20180218.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180206_20180302.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180206_20180314.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180206_20180326.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180206_20180407.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180218_20180302.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180218_20180314.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180218_20180326.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180218_20180407.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180218_20180419.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180302_20180314.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180302_20180326.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180302_20180407.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180302_20180419.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180302_20180501.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180314_20180326.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180314_20180407.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180314_20180419.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180314_20180501.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180314_20180513.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180326_20180407.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180326_20180419.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180326_20180501.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180326_20180513.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180326_20180525.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180407_20180419.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180407_20180501.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180407_20180513.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180407_20180525.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180407_20180606.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180419_20180501.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180419_20180513.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180419_20180525.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180419_20180606.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180419_20180618.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180501_20180513.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180501_20180525.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180501_20180606.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180501_20180618.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180501_20180630.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180513_20180525.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180513_20180606.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180513_20180618.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180513_20180630.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180513_20180712.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180525_20180606.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180525_20180618.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180525_20180630.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180525_20180712.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180525_20180724.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180606_20180618.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180606_20180630.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180606_20180712.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180606_20180724.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180606_20180805.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180618_20180630.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180618_20180712.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180618_20180724.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180618_20180805.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180618_20180817.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180630_20180712.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180630_20180724.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180630_20180805.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180630_20180817.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180630_20180829.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180712_20180724.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180712_20180805.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180712_20180817.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180712_20180829.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180712_20180910.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180724_20180805.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180724_20180817.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180724_20180829.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180724_20180910.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180724_20180922.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180805_20180817.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180805_20180829.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180805_20180910.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180805_20180922.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180805_20181004.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180817_20180829.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180817_20180910.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180817_20180922.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180817_20181004.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180817_20181016.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180829_20180910.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180829_20180922.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180829_20181004.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180829_20181016.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180829_20181028.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180910_20180922.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180910_20181004.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180910_20181016.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180910_20181028.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180910_20181109.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180922_20181004.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180922_20181016.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180922_20181028.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180922_20181109.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20180922_20181121.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181004_20181016.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181004_20181028.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181004_20181109.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181004_20181121.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181004_20181203.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181016_20181028.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181016_20181109.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181016_20181121.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181016_20181203.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181016_20181215.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181028_20181109.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181028_20181121.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181028_20181203.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181028_20181215.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181028_20181227.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181109_20181121.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181109_20181203.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181109_20181215.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181109_20181227.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181109_20190108.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181121_20181203.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181121_20181215.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181121_20181227.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181121_20190108.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181121_20190120.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181203_20181215.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181203_20181227.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181203_20190108.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181203_20190120.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181203_20190201.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181215_20181227.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181215_20190108.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181215_20190120.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181215_20190201.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181215_20190213.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181227_20190108.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181227_20190120.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181227_20190201.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181227_20190213.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20181227_20190225.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190108_20190120.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190108_20190201.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190108_20190213.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190108_20190225.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190108_20190309.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190120_20190201.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190120_20190213.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190120_20190225.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190120_20190309.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190120_20190321.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190201_20190213.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190201_20190225.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190201_20190309.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190201_20190321.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190201_20190402.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190213_20190225.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190213_20190309.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190213_20190321.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190213_20190402.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190213_20190414.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190225_20190309.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190225_20190321.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190225_20190402.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190225_20190414.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190225_20190426.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190309_20190321.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190309_20190402.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190309_20190414.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190309_20190426.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190309_20190508.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190321_20190402.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190321_20190414.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190321_20190426.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190321_20190508.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190321_20190520.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190402_20190414.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190402_20190426.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190402_20190508.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190402_20190520.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190402_20190601.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190414_20190426.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190414_20190508.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190414_20190520.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190414_20190601.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190414_20190613.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190426_20190508.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190426_20190520.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190426_20190601.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190426_20190613.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190426_20190625.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190508_20190520.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190508_20190601.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190508_20190613.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190508_20190625.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190508_20190707.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190520_20190601.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190520_20190613.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190520_20190625.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190520_20190707.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190520_20190719.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190601_20190613.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190601_20190625.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190601_20190707.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190601_20190719.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190601_20190731.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190613_20190625.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190613_20190707.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190613_20190719.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190613_20190731.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190613_20190812.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190625_20190707.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190625_20190719.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190625_20190731.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190625_20190812.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190625_20190824.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190707_20190719.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190707_20190731.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190707_20190812.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190707_20190824.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190707_20190905.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190719_20190731.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190719_20190812.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190719_20190824.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190719_20190905.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190719_20190917.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190731_20190812.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190731_20190824.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190731_20190905.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190731_20190917.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190731_20190929.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190812_20190824.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190812_20190905.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190812_20190917.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190812_20190929.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190812_20191011.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190824_20190905.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190824_20190917.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190824_20190929.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190824_20191011.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190824_20191023.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190905_20190917.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190905_20190929.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190905_20191011.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190905_20191023.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190905_20191104.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190917_20190929.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190917_20191011.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190917_20191023.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190917_20191104.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190917_20191116.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190929_20191011.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190929_20191023.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190929_20191104.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190929_20191116.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20190929_20191128.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191011_20191023.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191011_20191104.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191011_20191116.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191011_20191128.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191011_20191210.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191023_20191104.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191023_20191116.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191023_20191128.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191023_20191210.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191023_20191222.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191104_20191116.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191104_20191128.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191104_20191210.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191104_20191222.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191104_20200103.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191116_20191128.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191116_20191210.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191116_20191222.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191116_20200103.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191116_20200115.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191128_20191210.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191128_20191222.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191128_20200103.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191128_20200115.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191128_20200127.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191210_20191222.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191210_20200103.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191210_20200115.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191210_20200127.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191210_20200208.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191222_20200103.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191222_20200115.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191222_20200127.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191222_20200208.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20191222_20200220.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200103_20200115.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200103_20200127.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200103_20200208.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200103_20200220.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200103_20200303.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200115_20200127.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200115_20200208.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200115_20200220.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200115_20200303.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200115_20200315.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200127_20200208.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200127_20200220.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200127_20200303.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200127_20200315.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200127_20200327.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200208_20200220.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200208_20200303.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200208_20200315.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200208_20200327.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200208_20200408.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200220_20200303.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200220_20200315.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200220_20200327.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200220_20200408.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200220_20200420.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200303_20200315.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200303_20200327.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200303_20200408.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200303_20200420.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200303_20200502.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200315_20200327.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200315_20200408.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200315_20200420.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200315_20200502.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200315_20200514.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200327_20200408.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200327_20200420.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200327_20200502.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200327_20200514.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200327_20200526.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200408_20200420.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200408_20200502.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200408_20200514.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200408_20200526.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200408_20200607.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200420_20200502.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200420_20200514.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200420_20200526.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200420_20200607.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200420_20200619.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200502_20200514.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200502_20200526.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200502_20200607.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200502_20200619.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200502_20200701.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200514_20200526.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200514_20200607.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200514_20200619.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200514_20200701.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200514_20200713.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200526_20200607.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200526_20200619.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200526_20200701.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200526_20200713.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200526_20200725.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200607_20200619.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200607_20200701.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200607_20200713.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200607_20200725.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200607_20200806.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200619_20200701.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200619_20200713.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200619_20200725.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200619_20200806.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200619_20200818.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200701_20200713.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200701_20200725.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200701_20200806.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200701_20200818.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200701_20200830.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200713_20200725.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200713_20200806.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200713_20200818.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200713_20200830.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200713_20200911.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200725_20200806.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200725_20200818.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200725_20200830.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200725_20200911.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200725_20200923.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200806_20200818.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200806_20200830.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200806_20200911.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200806_20200923.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200806_20201005.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200818_20200830.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200818_20200911.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200818_20200923.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200818_20201005.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200818_20201017.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200830_20200911.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200830_20200923.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200830_20201005.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200830_20201017.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200830_20201029.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200911_20200923.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200911_20201005.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200911_20201017.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200911_20201029.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200911_20201110.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200923_20201005.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200923_20201017.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200923_20201029.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200923_20201110.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20200923_20201122.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201005_20201017.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201005_20201029.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201005_20201110.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201005_20201122.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201005_20201204.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201017_20201029.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201017_20201110.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201017_20201122.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201017_20201204.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201017_20201216.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201029_20201110.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201029_20201122.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201029_20201204.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201029_20201216.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201029_20201228.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201110_20201122.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201110_20201204.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201110_20201216.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201110_20201228.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201122_20201204.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201122_20201216.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201122_20201228.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201204_20201216.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201204_20201228.dim',
#  '/data1/data/sar_jhb_dumps/dinsar/20201216_20201228.dim']

# %%
#'SRTM 1Sec HGT'
source = b[0]
# !gpt AddElevation -Ssource=$source -PdemName='SRTM 1Sec HGT' -t $dem_dir/dem.dim
# !gpt Terrain-Correction -t $dem_dir/dem.dim  -PdemName="SRTM 1Sec HGT" {"\""+source_path+"\""}
# Out:
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# Executing operator...
# 20%....30%.....42%....52%54%....64%.....76%....86%....96%.. done.
# INFO: org.esa.snap.core.gpf.common.WriteOp: Start writing product 20171102_20180101 to /data1/data/sar_jhb_dumps/mintpy/dem.dim
# Writing...
# ..12%..22%....32%....42%.....54%....64%....74%.....86%....96%.. done.
# INFO: org.esa.snap.core.gpf.common.WriteOp: End writing product dem to /data1/data/sar_jhb_dumps/mintpy/dem.dim
# INFO: org.esa.snap.core.gpf.common.WriteOp: Time:  2.826 s total,  1.708 ms per line, 0.000328 ms per pixel

# %%
# !gpt graph/mintpy_subset.xml -Psource=$source -Pcoh_band=$coh_band -Punw_band=$unw_band -Ptarget_unw=$target_unw -Ptarget_coh=$target_coh

# %%
# b  = !ls $mintpy_dir
# POLYGON="'POLYGON((27.115 -25.886,28.847 -25.886,28.847 -26.680,27.115 -26.680,27.115 -25.886))'"

# %%
# b

# %%
# for i in range(len(b)):    
#     source = b[i]
#     print(source)
#     source_name = b[i]
#     !mkdir $tc_subset_dir/$source_name    
#     source_coh = "{}/{}/{}_coh_tc.dim".format(mintpy_dir,source_name,source_name)
#     print(source_coh)
#     target_coh = "{}/{}/{}_coh_tc.dim".format(tc_subset_dir,source_name,source_name)
#     print(target_coh)
#     source_unw = "{}/{}/{}_unw_tc.dim".format(mintpy_dir,source_name,source_name)
#     print(source_unw)
#     target_unw = "{}/{}/{}_unw_tc.dim".format(tc_subset_dir,source_name,source_name)
#     print(target_unw)
# #     c = !ls $tc_subset_dir/$source_name | grep *.dim
# #     print(c)
# #     if len(c) == 0:
# #         !gpt Subset -Ssource=$source_coh -PgeoRegion=$POLYGON -PcopyMetadata=true -t $target_coh
#     !gpt Subset -Ssource=$source_unw -PgeoRegion=$POLYGON -PcopyMetadata=true -t $target_unw
