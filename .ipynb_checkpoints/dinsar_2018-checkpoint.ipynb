# %%
data_dir = "/data1/data/sar_rio_dumps/"
dinsar_dir = "/data1/data/sar_rio_dumps/dinsar/"
# graph = "graph/TOPSAR\ Coreg\ Interferogram\ VV\ IW\ 2_3\ B\ 8_9.xml"
graph = "TOPSAR\ Coreg\ Interferogram\ VV\ IW\ 2\ B\ 9.xml"
overlap = 5
# !mkdir $dinsar_dir
# Out:
# mkdir: cannot create directory ‘/data1/data/sar_rio_dumps/dinsar/’: File exists

# %%
a = !ls $data_dir*.zip
a.sort()
print(a[0], a[1])
# Out:
# /data1/data/sar_rio_dumps/S1B_IW_SLC__1SDV_20171111T082129_20171111T082156_008231_00E8E9_5F93.zip /data1/data/sar_rio_dumps/S1B_IW_SLC__1SDV_20171123T082128_20171123T082155_008406_00EE34_21E0.zip

# %%
for i in range(overlap,overlap+31):
    for j in range(overlap, 0, -1):
        print(a[i-j][43:51],a[i][43:51])
        master = a[i-j]
        slave = a[i]
        target_name = "{}_{}".format(a[i-j][43:51],a[i][43:51])
        target = "{}{}_{}.dim".format(dinsar_dir,a[i-j][43:51],a[i][43:51])
        c = !ls $dinsar_dir | grep $target_name
        print(c)
        if len(c) == 0:
            # !gpt graph/$graph -Pmaster=$master -Pslave=$slave -Ptarget=$target -c 64G -q 9
# Out:
# 20171111 20180110
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
#  done.
#
# Error: [NodeId: TopoPhaseRemoval] Source product should first be deburst.
# -- org.jblas INFO Deleting /tmp/jblas2688732521740528700/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas2688732521740528700/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas2688732521740528700/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas2688732521740528700/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas2688732521740528700
# 20171123 20180110
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
#  done.
#
# Error: [NodeId: TopoPhaseRemoval] Source product should first be deburst.
# -- org.jblas INFO Deleting /tmp/jblas1284681754948122785/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas1284681754948122785/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas1284681754948122785/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas1284681754948122785/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas1284681754948122785
# 20171205 20180110
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
#  done.
#
# Error: [NodeId: TopoPhaseRemoval] Source product should first be deburst.
# -- org.jblas INFO Deleting /tmp/jblas1843386475771372082/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas1843386475771372082/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas1843386475771372082/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas1843386475771372082/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas1843386475771372082
# 20171217 20180110
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
#  done.
#
# Error: [NodeId: TopoPhaseRemoval] Source product should first be deburst.
# -- org.jblas INFO Deleting /tmp/jblas795940970789498793/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas795940970789498793/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas795940970789498793/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas795940970789498793/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas795940970789498793
# 20171229 20180110
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
#  done.
#
# Error: [NodeId: TopoPhaseRemoval] Source product should first be deburst.
# -- org.jblas INFO Deleting /tmp/jblas1091382545495445869/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas1091382545495445869/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas1091382545495445869/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas1091382545495445869/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas1091382545495445869
# 20171123 20180122
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
#  done.
#
# Error: [NodeId: TopoPhaseRemoval] Source product should first be deburst.
# -- org.jblas INFO Deleting /tmp/jblas1025995675041669330/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas1025995675041669330/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas1025995675041669330/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas1025995675041669330/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas1025995675041669330
# 20171205 20180122
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
#  done.
#
# Error: [NodeId: TopoPhaseRemoval] Source product should first be deburst.
# -- org.jblas INFO Deleting /tmp/jblas3184383821575338142/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas3184383821575338142/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas3184383821575338142/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas3184383821575338142/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas3184383821575338142
# 20171217 20180122
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
#  done.
#
# Error: [NodeId: TopoPhaseRemoval] Source product should first be deburst.
# -- org.jblas INFO Deleting /tmp/jblas4604091291726857266/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas4604091291726857266/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas4604091291726857266/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas4604091291726857266/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas4604091291726857266
# 20171229 20180122
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
#  done.
#
# Error: [NodeId: TopoPhaseRemoval] Source product should first be deburst.
# -- org.jblas INFO Deleting /tmp/jblas3061023617882855921/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas3061023617882855921/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas3061023617882855921/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas3061023617882855921/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas3061023617882855921
# 20180110 20180122
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
