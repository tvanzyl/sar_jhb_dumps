# %%
from mintpy.utils import *
import mintpy.utils as mpu
import mintpy.utils.readfile
import mintpy.utils.utils
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib
import numpy as np
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

# %%
sns.set_theme()
sns.set_style("ticks")
sns.set_context("paper")
# sns.set_theme(style="white") #, font_scale=0.5)
plt.style.use(['seaborn-paper', 'seaborn-ticks'])
sns.set_color_codes()

# %%
matplotlib.rcParams['lines.linewidth']
matplotlib.rcParams['axes.linewidth']
plt.style.available
matplotlib.use("pgf")
matplotlib.rcParams.update({    
    'font.family': 'serif',
    'font.serif': [],       # use latex default serif font
    'font.sans-serif': [],  # use a specific sans-serif font
    'font.monospace': [],   # use a specific sans-serif font
    'text.usetex': True,
    'pgf.rcfonts': False,
    'pgf.texsystem': 'pdflatex',
    'lines.linewidth': 0.7,
    'axes.linewidth': 0.6,
    'axes.unicode_minus': False
})

golden_ratio = (5**.5 - 1) / 2

width  = 3.48761
height = width*golden_ratio
print(width,height)
# Out:
# 3.48761 2.155461519504021

# %%
mask_data, mask_attr = mpu.readfile.read('/data1/data/sar_jhb_dumps/mintpy/maskROI.h5')

# %%
mask_attr
# Out:
# {'ALOOKS': '2',
#  'ANTENNA_SIDE': '-1',
#  'AZIMUTH_PIXEL_SIZE': '35.246762617962254',
#  'CENTER_LINE_UTC': '60414.0',
#  'DATA_TYPE': 'bool',
#  'DATE12': '20171102_20201228',
#  'EARTH_RADIUS': '6372916.232867104',
#  'END_DATE': '20201228',
#  'FILE_LENGTH': '2785',
#  'FILE_PATH': '/data1/data/sar_jhb_dumps/mintpy/maskROI.h5',
#  'FILE_TYPE': 'mask',
#  'HEADING': '-1.260372609972952e+01',
#  'HEIGHT': '707266.2511479785',
#  'INCIDENCE_ANGLE': '3.901818002255490e+01',
#  'LAT_REF1': '-26.6842879645658',
#  'LAT_REF2': '-26.4644430053711',
#  'LAT_REF3': '-26.35441583861653',
#  'LAT_REF4': '-26.13532301691702',
#  'LENGTH': '36',
#  'LONG_REF1': '27.21457286093934',
#  'LONG_REF2': '28.13658642471043',
#  'LONG_REF3': '27.12070330797209',
#  'LONG_REF4': '28.04000415979327',
#  'ORBIT_DIRECTION': 'ASCENDING',
#  'PLATFORM': 'sen',
#  'PRF': '1717.128973878037',
#  'PROCESSOR': 'snap',
#  'PROJECT_NAME': 'mintpy',
#  'P_BASELINE_BOTTOM_HDR': '38.81139373779297',
#  'P_BASELINE_TOP_HDR': '38.81139373779297',
#  'RANGE_PIXEL_SIZE': '30.725940457888374',
#  'REF_DATE': '20180101',
#  'REF_LAT': '-26.2314735139096',
#  'REF_LON': '28.03216438217346',
#  'REF_X': '1',
#  'REF_Y': '13',
#  'RLOOKS': '9',
#  'SLANT_RANGE_DISTANCE': '882231.9134755051',
#  'STARTING_RANGE': '849414.4911322432',
#  'START_DATE': '20171102',
#  'SUBSET_XMAX': '3256',
#  'SUBSET_XMIN': '3217',
#  'SUBSET_YMAX': '1235',
#  'SUBSET_YMIN': '1199',
#  'UNIT': 'm/year',
#  'WAVELENGTH': '0.05546576',
#  'WIDTH': '39',
#  'XMAX': '38',
#  'X_FIRST': '28.03173688520401',
#  'X_STEP': '0.00028499797963376196',
#  'YMAX': '35',
#  'Y_FIRST': '-26.227626041184543',
#  'Y_STEP': '-0.00028499797963376196',
#  'mintpy.deramp': 'linear',
#  'mintpy.deramp.maskFile': 'maskTempCoh.h5',
#  'mintpy.load.corFile': '../interferograms/*/*/coh_*.img',
#  'mintpy.load.demFile': '../dem_tc.data/elevation_VV.img',
#  'mintpy.load.processor': 'snap',
#  'mintpy.load.unwFile': '../interferograms/*/*/Unw_*.img',
#  'mintpy.network.coherenceBased': 'no',
#  'mintpy.network.minCoherence': '0.35',
#  'mintpy.networkInversion.maskDataset': 'coherence',
#  'mintpy.networkInversion.maskThreshold': '0.26',
#  'mintpy.networkInversion.minNormVelocity': 'True',
#  'mintpy.networkInversion.minRedundancy': '2.0',
#  'mintpy.networkInversion.numIfgram': '460',
#  'mintpy.networkInversion.obsDatasetName': 'unwrapPhase',
#  'mintpy.networkInversion.weightFunc': 'var',
#  'mintpy.reference.date': '20180101',
#  'mintpy.reference.yx': '13, 1',
#  'mintpy.subset.lalo': '-26.2277:-26.2378, 28.0320:28.0430',
#  'mintpy.topographicResidual.excludeDate': "['exclude_date.txt']",
#  'mintpy.topographicResidual.phaseVelocity': 'False',
#  'mintpy.topographicResidual.polyOrder': '2',
#  'mintpy.topographicResidual.stepFuncDate': '[]',
#  'mintpy.velocity.bootstrap': 'False',
#  'mintpy.velocity.bootstrapCount': '400',
#  'mintpy.velocity.endDate': '20201228',
#  'mintpy.velocity.excludeDate': "['20171126', '20180206', '20180419', '20181004', '20190402', '20190414', '20191128']",
#  'mintpy.velocity.startDate': '20171102',
#  'OG_FILE_PATH': '/data1/data/sar_jhb_dumps/mintpy/robinsons_deep/velocity.h5'}

# %%
plt.imshow(mask_data)

# %%
mask_data_temp, mask_attr_temp = mpu.readfile.read('/data1/data/sar_jhb_dumps/mintpy/robinsons_deep/maskTempCoh.h5')
plt.imshow(mask_data_temp)

# %%
plt.imshow(mask_data*mask_data_temp)
mask_data = mask_data*mask_data_temp

# %%
ts_file = '/data1/data/sar_jhb_dumps/mintpy/robinsons_deep/timeseries_ERA5_ramp_demErr.h5'

# %%
ts_data, ts_attr = mpu.readfile.read(ts_file)

# %%
ts_attr
# Out:
# {'ALOOKS': '2',
#  'ANTENNA_SIDE': '-1',
#  'AZIMUTH_PIXEL_SIZE': '35.246762617962254',
#  'CENTER_LINE_UTC': '60414.0',
#  'DATA_TYPE': 'float32',
#  'DATE12': '171102-180101',
#  'EARTH_RADIUS': '6372916.232867104',
#  'END_DATE': '20201228',
#  'FILE_LENGTH': '2785',
#  'FILE_PATH': '/data1/data/sar_jhb_dumps/mintpy/robinsons_deep/timeseries_ERA5_ramp_demErr.h5',
#  'FILE_TYPE': 'timeseries',
#  'HEADING': '-1.260372609972952e+01',
#  'HEIGHT': '707266.2511479785',
#  'INCIDENCE_ANGLE': '3.901818002255490e+01',
#  'LAT_REF1': '-26.6842879645658',
#  'LAT_REF2': '-26.4644430053711',
#  'LAT_REF3': '-26.35441583861653',
#  'LAT_REF4': '-26.13532301691702',
#  'LENGTH': '36',
#  'LONG_REF1': '27.21457286093934',
#  'LONG_REF2': '28.13658642471043',
#  'LONG_REF3': '27.12070330797209',
#  'LONG_REF4': '28.04000415979327',
#  'ORBIT_DIRECTION': 'ASCENDING',
#  'PLATFORM': 'sen',
#  'PRF': '1717.128973878037',
#  'PROCESSOR': 'snap',
#  'PROJECT_NAME': 'mintpy',
#  'P_BASELINE_BOTTOM_HDR': '38.81139373779297',
#  'P_BASELINE_TOP_HDR': '38.81139373779297',
#  'RANGE_PIXEL_SIZE': '30.725940457888374',
#  'REF_DATE': '20180101',
#  'REF_LAT': '-26.231758511889232',
#  'REF_LON': '28.03216438217346',
#  'REF_X': '1',
#  'REF_Y': '14',
#  'RLOOKS': '9',
#  'SLANT_RANGE_DISTANCE': '882231.9134755051',
#  'STARTING_RANGE': '849414.4911322432',
#  'START_DATE': '20171114',
#  'SUBSET_XMAX': '3256',
#  'SUBSET_XMIN': '3217',
#  'SUBSET_YMAX': '1235',
#  'SUBSET_YMIN': '1199',
#  'UNIT': 'm',
#  'WAVELENGTH': '0.05546576',
#  'WIDTH': '39',
#  'XMAX': '38',
#  'X_FIRST': '28.03173688520401',
#  'X_STEP': '0.00028499797963376196',
#  'YMAX': '35',
#  'Y_FIRST': '-26.227626041184543',
#  'Y_STEP': '-0.00028499797963376196',
#  'mintpy.deramp': 'linear',
#  'mintpy.deramp.maskFile': 'maskTempCoh.h5',
#  'mintpy.load.corFile': '../interferograms/*/*/coh_*.img',
#  'mintpy.load.demFile': '../dem_tc.data/elevation_VV.img',
#  'mintpy.load.processor': 'snap',
#  'mintpy.load.unwFile': '../interferograms/*/*/Unw_*.img',
#  'mintpy.network.coherenceBased': 'yes',
#  'mintpy.network.connNumMax': '4',
#  'mintpy.network.keepMinSpanTree': 'yes',
#  'mintpy.network.minCoherence': '0.38',
#  'mintpy.network.perpBaseMax': '150',
#  'mintpy.network.tempBaseMax': '60',
#  'mintpy.networkInversion.maskDataset': 'coherence',
#  'mintpy.networkInversion.maskThreshold': '0.26',
#  'mintpy.networkInversion.minNormVelocity': 'True',
#  'mintpy.networkInversion.minRedundancy': '1.0',
#  'mintpy.networkInversion.minTempCoh': '0.60',
#  'mintpy.networkInversion.numIfgram': '357',
#  'mintpy.networkInversion.obsDatasetName': 'unwrapPhase',
#  'mintpy.networkInversion.weightFunc': 'var',
#  'mintpy.reference.date': '20180101',
#  'mintpy.reference.yx': '14, 1',
#  'mintpy.subset.lalo': '-26.2277:-26.2378, 28.0320:28.0430',
#  'mintpy.topographicResidual.excludeDate': "['exclude_date.txt']",
#  'mintpy.topographicResidual.phaseVelocity': 'False',
#  'mintpy.topographicResidual.polyOrder': '2',
#  'mintpy.topographicResidual.stepFuncDate': '[]',
#  'OG_FILE_PATH': '/data1/data/sar_jhb_dumps/mintpy/interferograms/20171102_20180101/20171102_20180101_unw_tc.data/Unw_Phase_ifg_02Nov2017_01Jan2018_VV.img'}

# %%
from mintpy.objects import (
    geometryDatasetNames,
    geometry,
    ifgramStack,
    timeseries,
)
from mintpy.utils import ptime, readfile

# %%
obj = timeseries(ts_file)

# %%
date_list = timeseries(ts_file).get_date_list()

# %%
the_dates, dis = mpu.utils.read_timeseries_yx(0,0, ts_file=ts_file)
# Out:
# input y / x: 0 / 0

# %%
fig =plt.figure()
plt.imshow(mask_data)
fig

# %%
a = open('/data1/data/sar_jhb_dumps/mintpy/robinsons_deep/exclude_date.txt').readlines()
a
# Out:
# ['20171126\n',
#  '20180206\n',
#  '20180419\n',
#  '20190321\n',
#  '20190414\n',
#  '20191128\n']

# %%
from mintpy import timeseries2velocity as ts2v

# %%
excludeDate = [x[:-1] for x in a]
# excludeDate.append('20180113')

# %%
class Inps:
    pass
inps1 = Inps()
inps1.timeseries_file = ts_file
inps1.outfile = '/tmp/velocity.h5'
inps1.startDate = '20180101'
# inps1.endDate = '20190630'
# inps1.startDate = '20190701'
# inps1.endDate = '20200630'
# inps1.startDate = '20200701'
inps1.endDate = '20201231'
inps1.excludeDate = excludeDate
inps1.key = readfile.read_attribute(inps1.timeseries_file)['FILE_TYPE']
inps1.polynomial = 1
inps1.bootstrap = False
inps1.periodic = [1.0]
inps1.step = []
inps1.ref_yx = None
inps1.ref_date = None
inps1.bootstrapCount = 400
inps1.maxMemory = 8 #GB

# %%
ts2v.run_timeseries2time_func(ts2v.read_date_info(inps1))
# Out:
# open timeseries file: timeseries_ERA5_ramp_demErr.h5
# exclude date:['20171126', '20180206', '20180419', '20190321', '20190414', '20191128']
# start date: 20180101
#   remove date: 20171114
#   remove date: 20171208
#   remove date: 20171220
# end date: 20201231
# --------------------------------------------------
# dates from input file: 96
# ['20171114', '20171126', '20171208', '20171220', '20180101', '20180113', '20180125', '20180206', '20180218', '20180302', '20180314', '20180326', '20180407', '20180419', '20180501', '20180513', '20180525', '20180606', '20180618', '20180630', '20180712', '20180724', '20180805', '20180817', '20180829', '20180910', '20180922', '20181004', '20181016', '20181028', '20181109', '20181121', '20181203', '20181215', '20181227', '20190108', '20190120', '20190201', '20190213', '20190225', '20190309', '20190321', '20190402', '20190414', '20190426', '20190508', '20190520', '20190601', '20190613', '20190625', '20190707', '20190719', '20190731', '20190812', '20190824', '20190905', '20190917', '20190929', '20191011', '20191023', '20191104', '20191116', '20191128', '20191210', '20191222', '20200103', '20200115', '20200127', '20200208', '20200220', '20200303', '20200315', '20200327', '20200408', '20200420', '20200502', '20200514', '20200526', '20200607', '20200619', '20200701', '20200713', '20200725', '20200806', '20200818', '20200830', '20200911', '20200923', '20201005', '20201017', '20201029', '20201110', '20201122', '20201204', '20201216', '20201228']
# --------------------------------------------------
# dates used to estimate the velocity: 87
# ['20180101', '20180113', '20180125', '20180218', '20180302', '20180314', '20180326', '20180407', '20180501', '20180513', '20180525', '20180606', '20180618', '20180630', '20180712', '20180724', '20180805', '20180817', '20180829', '20180910', '20180922', '20181004', '20181016', '20181028', '20181109', '20181121', '20181203', '20181215', '20181227', '20190108', '20190120', '20190201', '20190213', '20190225', '20190309', '20190402', '20190426', '20190508', '20190520', '20190601', '20190613', '20190625', '20190707', '20190719', '20190731', '20190812', '20190824', '20190905', '20190917', '20190929', '20191011', '20191023', '20191104', '20191116', '20191210', '20191222', '20200103', '20200115', '20200127', '20200208', '20200220', '20200303', '20200315', '20200327', '20200408', '20200420', '20200502', '20200514', '20200526', '20200607', '20200619', '20200701', '20200713', '20200725', '20200806', '20200818', '20200830', '20200911', '20200923', '20201005', '20201017', '20201029', '20201110', '20201122', '20201204', '20201216', '20201228']
# --------------------------------------------------
# estimate deformation model with the following assumed time functions:
# polynomial : 1
# periodic   : [1.0]
# step       : []
# add/update the following configuration metadata:
# ['startDate', 'endDate', 'excludeDate', 'bootstrap', 'bootstrapCount']
# --------------------------------------------------
# create HDF5 file: /tmp/velocity.h5 with w mode
# create dataset  : velocity    of <class 'numpy.float32'>   in size of (36, 39)             with compression = None
# create dataset  : velocityStd of <class 'numpy.float32'>   in size of (36, 39)             with compression = None
# create dataset  : annualAmp   of <class 'numpy.float32'>   in size of (36, 39)             with compression = None
# close  HDF5 file: /tmp/velocity.h5
# add /velocity    attribute: UNIT = m/year
# add /velocityStd attribute: UNIT = m/year
# add /annualAmp   attribute: UNIT = m
# reading data from file /data1/data/sar_jhb_dumps/mintpy/robinsons_deep/timeseries_ERA5_ramp_demErr.h5 ...
# skip pixels with zero/nan value in all acquisitions
# number of pixels to invert: 1365 out of 1404 (97.2%)
# estimate time functions via linalg.lstsq ...
# open file: /tmp/velocity.h5 with "a" mode
# write dataset /velocity             block: [0, 36, 0, 39]
# write dataset /velocityStd          block: [0, 36, 0, 39]
# write dataset /annualAmp            block: [0, 36, 0, 39]
# close HDF5 file /tmp/velocity.h5
# '/tmp/velocity.h5'

# %%
vel_ts, vel_ts_atr = mpu.readfile.read('/tmp/velocity.h5', datasetName='velocity')
vel_std_ts, vel_std_ts_atr = mpu.readfile.read('/tmp/velocity.h5', datasetName='velocityStd')

# %% [markdown]
# 1 lbs = 0,000453592
#
# 2000 lbs = 0.9071847
#
# 1700 lbs = 0.771107
#
# 1200 lbs = 0.5443108
#
# 700 lbs = 0.317515
#
# 400 lbs = 0.181437

# %%
PIXEL_AREA = float(ts_attr['AZIMUTH_PIXEL_SIZE'])*float(ts_attr['RANGE_PIXEL_SIZE'])

# %%
mask_positive = vel_ts>0

# %%
mask_data_fill = mask_data.copy()
for i in range(1,mask_data.shape[0]-1):
    for j in range(1,mask_data.shape[1]-1):        
        if mask_data_fill[i,j] == False:
            mask_data_fill[i,j] = mask_data_fill[i-1:i+2,j-1:j+2].astype(int).sum() >= 6

# %%
fig = plt.figure()
plt.imshow(mask_data_fill)
fig

# %%
(vel_ts*mask_data).mean()*100
# Out:
# 0.17048115842044353

# %%
(vel_ts*(mask_data)*(PIXEL_AREA)/0.764555*0.9071847*100).sum()*3.0/mask_data.sum()*mask_data_fill.sum()
# Out:
# 959193.8343465045

# %%
0.764555*0.9071847
# Out:
# 0.6935925983085

# %%
(vel_std_ts*(mask_data)*(PIXEL_AREA)/0.764555*0.9071847*100).sum()*3.0/mask_data.sum()*mask_data_fill.sum()
# Out:
# 36063.201373717704

# %%
#Q3-Q4 2018 
83102+15066
#Q3-Q4 2018- Q1-Q2 2019
278116 - 255655
#2018-2020
83102+15066+255655+472297+235267
# Out:
# 1061387

# %%
(931751.84)/1061387
# Out:
# 0.8778624950183109

# %%
# ts_Q_vel = []
# ts_Q_velstd = []
# ts_Q_acc = []
# ts_Q_accstd = []
# for startDate, endDate in zip(['20171231',
#                               '20180331',              
#                               '20180630',
#                               '20180930',
#                               '20181231',
#                               '20190331',
#                               '20190630',
#                               '20190930',
#                               '20191231',
#                               '20200331', 
#                               '20200630', 
#                               '20200930'],
#                               ['20180331',              
#                               '20180630',
#                               '20180930',
#                               '20181231',
#                               '20190331',
#                               '20190630',
#                               '20190930',
#                               '20191231',
#                               '20200331', 
#                               '20200630', 
#                               '20200930',
#                               '20201231']):
#     print(startDate,endDate)
#     class Inps:
#         pass
#     inps = Inps()
#     inps.timeseries_file = ts_file
#     inps.outfile = '/tmp/velocity.h5'
#     inps.startDate = startDate
#     inps.endDate = endDate
#     inps.excludeDate = excludeDate
#     inps.key = readfile.read_attribute(inps.timeseries_file)['FILE_TYPE']
#     inps.polynomial = 1
#     inps.bootstrap = False
#     inps.periodic = [0.25]
#     inps.step = []
#     inps.ref_yx = None
#     inps.ref_date = None
#     inps.bootstrapCount = 400
#     inps.maxMemory = 8 #GB
#     ts2v.run_timeseries2time_func(ts2v.read_date_info(inps))
#     vel_ts, vel_ts_atr = mpu.readfile.read('/tmp/velocity.h5', datasetName='velocity')
#     vel_std_ts, vel_std_ts_atr = mpu.readfile.read('/tmp/velocity.h5', datasetName='velocityStd')    
#     ts_Q_vel.append(vel_ts)
#     ts_Q_velstd.append(vel_std_ts)

# %%
ts_cum_sum = (ts_data*mask_data).sum(axis=(1,2))/mask_data.sum()
ts_cum_sum.shape
# Out:
# (96,)

# %%
df_ts_data = pd.DataFrame(ts_cum_sum, columns=['Displacement'], index=pd.DatetimeIndex(the_dates))

# %%
df_ts_data = df_ts_data.resample('12D').mean().rename(columns=lambda x: 'Displacement')

# %%
df_ts_data['Count'] = 1

# %%
for i in excludeDate:
    df_ts_data.loc[i[:8]:i[:8]] = 0

# %%
df_ts_data['Days'] = 1

# %%
# df_ts_data.Displacement *= 365
df_ts_data.Displacement *= 100 #convert to cm
df_ts_data.Displacement /= 12 # get a daily value

# %%
# inps2 = ts2v.read_date_info(inps)
# inps2.periodic = []
# model, num_param = ts2v.read_inps2model(inps2)
# G = ts2v.timeseries.get_design_matrix4time_func(inps2.dateList, model)
# # G, m[:, mask], e2 = estimate_time_func(inps.dateList, ts_data, model)

# %%
# df_ts_data.loc[inps2.dateList].Displacement.values

# %%
# np.linalg.lstsq(G, df_ts_data.loc[inps1.dateList].Displacement.values, rcond=None)

# %%
# np.linalg.lstsq(np.c_[np.ones(96),np.arange(96)/96*3], df_ts_data.Displacement.values, rcond=None)

# %%
# np.linalg.lstsq(G, df_ts_Q.Adj_Displacement.values, rcond=None)

# %%
# np.linalg.lstsq(np.c_[np.ones(92),np.arange(92)/92*3], df_ts_Q.Adj_Displacement.values, rcond=None)

# %%
df_ts_B = pd.DataFrame(ts_cum_sum, columns=['Displacement'], index=pd.DatetimeIndex(the_dates))
df_ts_B.loc[excludeDate, 'Displacement'] = np.nan
df_ts_B  = df_ts_B['2018-01-01':]
df_ts_B.Displacement *= 100
df_ts_B.Displacement /= 12
df_ts_B
# Out:
#             Displacement
# 2018-01-01      0.016399
# 2018-01-13     -0.044055
# 2018-01-25      0.103471
# 2018-02-06           NaN
# 2018-02-18      0.147425
# ...                  ...
# 2020-11-10      0.743328
# 2020-11-22      0.750799
# 2020-12-04      0.824382
# 2020-12-16      0.857175
# 2020-12-28      0.863138
#
# [92 rows x 1 columns]

# %%
df_ts_data.loc[excludeDate, 'Displacement'] = np.nan
df_ts_data.Displacement.interpolate(method='linear')
# Out:
# 2017-11-14    0.000010
# 2017-11-26    0.001607
# 2017-12-08    0.003204
# 2017-12-20   -0.000774
# 2018-01-01    0.001968
#                 ...
# 2020-11-10    0.089199
# 2020-11-22    0.090096
# 2020-12-04    0.098926
# 2020-12-16    0.102861
# 2020-12-28    0.103577
# Freq: 12D, Name: Displacement, Length: 96, dtype: float32

# %%
df_ts_A = df_ts_data.copy()
df_ts_A.loc[excludeDate, 'Displacement'] = np.nan
df_ts_A.Displacement = df_ts_A.Displacement.interpolate(method='linear').diff()
df_ts_A['Velocity'] = df_ts_A.Displacement
df_ts_A = df_ts_A.resample('D').last()
df_ts_A = df_ts_A.bfill(limit=11) \
                  .resample('A') \
                  .sum()
df_ts_A.Displacement = df_ts_A.Displacement.cumsum()
df_ts_A.Velocity = df_ts_A.Velocity/df_ts_A.Days*365.25
df_ts_A = df_ts_A['2018-01-01':]
df_ts_A
# Out:
#             Displacement  Count   Days  Int_Displacement  Velocity
# 2018-12-31      7.898758  341.0  365.0          0.391977  0.371484
# 2019-12-31     17.610504  329.0  365.0          0.713904  0.322147
# 2020-12-31     29.337311  363.0  363.0          1.242794  0.532168

# %%
df_ts_Q = df_ts_data.copy()
df_ts_Q.loc[excludeDate, 'Displacement'] = np.nan
df_ts_Q.Displacement = df_ts_Q.Displacement.interpolate(method='linear')
df_ts_Q['Velocity'] = df_ts_Q.Displacement.diff()
df_ts_Q = df_ts_Q.resample('D').last()
df_ts_Q = df_ts_Q.bfill(limit=11) \
                 .resample('Q') \
                 .sum()
df_ts_Q.Velocity  = df_ts_Q.Velocity/df_ts_Q.Days*365.25
df_ts_Q['Adj_Displacement'] = df_ts_Q.Displacement/df_ts_Q.Days
df_ts_Q['Acceleration'] = df_ts_Q.Velocity.diff()
df_ts_Q = df_ts_Q['2018-01-01':]
df_ts_Q
# Out:
#             Displacement  Count  Days  Velocity  Adj_Displacement  \
# 2018-03-31      1.225395   78.0  90.0  0.997290          0.013615
# 2018-06-30      1.857824   79.0  91.0 -0.063062          0.020416
# 2018-09-30      2.067271   92.0  92.0 -0.237623          0.022470
# 2018-12-31      2.748269   92.0  92.0  0.798213          0.029872
# 2019-03-31      3.242453   78.0  90.0  0.729707          0.036027
# 2019-06-30      4.019448   79.0  91.0 -0.019309          0.044170
# 2019-09-30      4.780758   92.0  92.0  0.398527          0.051965
# 2019-12-31      5.567845   80.0  92.0  0.184810          0.060520
# 2020-03-31      5.900432   91.0  91.0  0.806657          0.064840
# 2020-06-30      7.138494   91.0  91.0  0.313210          0.078445
# 2020-09-30      7.996007   92.0  92.0  0.252875          0.086913
# 2020-12-31      8.302376   89.0  89.0  0.764098          0.093285
#
#             Acceleration
# 2018-03-31      0.839416
# 2018-06-30     -1.060352
# 2018-09-30     -0.174561
# 2018-12-31      1.035836
# 2019-03-31     -0.068506
# 2019-06-30     -0.749016
# 2019-09-30      0.417836
# 2019-12-31     -0.213718
# 2020-03-31      0.621847
# 2020-06-30     -0.493446
# 2020-09-30     -0.060335
# 2020-12-31      0.511223

# %%
# for i, d in zip(ts_Q_vel, df_ts_Q.index):
#      df_ts_Q.loc[d, 'Velocity_new'] = ((i*mask_data).sum()/mask_data.sum()*100)

# %%
df_ts_M = df_ts_data.copy()
df_ts_M.loc[excludeDate, 'Displacement'] = np.nan
df_ts_M.Displacement = df_ts_M.Displacement.interpolate(method='linear')
df_ts_M['Velocity'] = df_ts_M.Displacement.diff()
df_ts_M = df_ts_M.resample('D').last()
df_ts_M = df_ts_M.bfill(limit=11) \
                 .resample('M') \
                 .sum()
df_ts_M.Velocity  = df_ts_M.Velocity/df_ts_M.Days*365.25
df_ts_M['Adj_Displacement'] = df_ts_M.Displacement/df_ts_M.Days
df_ts_M['Acceleration'] = df_ts_M.Velocity.diff()
df_ts_M = df_ts_M['2018-01-01':]
df_ts_M
# Out:
#             Displacement  Count  Days  Velocity  Adj_Displacement  \
# 2018-01-31      0.177849   25.0  31.0  1.696042          0.005737
# 2018-02-28      0.419627   22.0  28.0 -0.162098          0.014987
# 2018-03-31      0.627919   31.0  31.0  1.345727          0.020255
# 2018-04-30      0.679678   18.0  30.0 -0.322651          0.022656
# 2018-05-31      0.601695   31.0  31.0 -0.106310          0.019410
# 2018-06-30      0.576451   30.0  30.0  0.241218          0.019215
# 2018-07-31      0.718254   31.0  31.0  0.694277          0.023169
# 2018-08-31      0.776792   31.0  31.0 -0.141016          0.025058
# 2018-09-30      0.572226   30.0  30.0 -1.300414          0.019074
# 2018-10-31      0.870752   31.0  31.0  1.513563          0.028089
# 2018-11-30      0.854852   30.0  30.0  0.328491          0.028495
# 2018-12-31      1.022665   31.0  31.0  0.537434          0.032989
# 2019-01-31      0.991639   31.0  31.0 -0.473142          0.031988
# 2019-02-28      0.977215   28.0  28.0  1.012890          0.034901
# 2019-03-31      1.273599   19.0  31.0  1.676779          0.041084
# 2019-04-30      1.291121   18.0  30.0 -1.056886          0.043037
# 2019-05-31      1.321402   31.0  31.0  0.595728          0.042626
# 2019-06-30      1.406925   30.0  30.0  0.382730          0.046897
# 2019-07-31      1.539173   31.0  31.0  0.499396          0.049651
# 2019-08-31      1.607975   31.0  31.0  0.167719          0.051870
# 2019-09-30      1.633610   30.0  30.0  0.532799          0.054454
# 2019-10-31      1.756073   31.0  31.0  0.665331          0.056648
# 2019-11-30      1.860246   18.0  30.0  0.527430          0.062008
# 2019-12-31      1.951526   31.0  31.0 -0.627279          0.062952
# 2020-01-31      1.869598   31.0  31.0  0.912745          0.060310
# 2020-02-29      1.730014   29.0  29.0 -1.320886          0.059656
# 2020-03-31      2.300820   31.0  31.0  2.690850          0.074220
# 2020-04-30      2.260892   30.0  30.0  0.171222          0.075363
# 2020-05-31      2.410136   31.0  31.0  0.198853          0.077746
# 2020-06-30      2.467466   30.0  30.0  0.573368          0.082249
# 2020-07-31      2.616448   31.0  31.0  0.302522          0.084402
# 2020-08-31      2.727269   31.0  31.0  0.627569          0.087976
# 2020-09-30      2.652290   30.0  30.0 -0.185609          0.088410
# 2020-10-31      2.664871   31.0  31.0  0.536997          0.085964
# 2020-11-30      2.764551   30.0  30.0  0.602436          0.092152
# 2020-12-31      2.872954   28.0  28.0  1.188742          0.102606
#
#             Acceleration
# 2018-01-31      1.752616
# 2018-02-28     -1.858140
# 2018-03-31      1.507825
# 2018-04-30     -1.668378
# 2018-05-31      0.216341
# 2018-06-30      0.347528
# 2018-07-31      0.453060
# 2018-08-31     -0.835293
# 2018-09-30     -1.159398
# 2018-10-31      2.813977
# 2018-11-30     -1.185073
# 2018-12-31      0.208944
# 2019-01-31     -1.010576
# 2019-02-28      1.486032
# 2019-03-31      0.663889
# 2019-04-30     -2.733665
# 2019-05-31      1.652614
# 2019-06-30     -0.212998
# 2019-07-31      0.116666
# 2019-08-31     -0.331678
# 2019-09-30      0.365080
# 2019-10-31      0.132532
# 2019-11-30     -0.137901
# 2019-12-31     -1.154708
# 2020-01-31      1.540024
# 2020-02-29     -2.233632
# 2020-03-31      4.011736
# 2020-04-30     -2.519627
# 2020-05-31      0.027630
# 2020-06-30      0.374516
# 2020-07-31     -0.270846
# 2020-08-31      0.325046
# 2020-09-30     -0.813178
# 2020-10-31      0.722606
# 2020-11-30      0.065439
# 2020-12-31      0.586306

# %%
#Q3-Q4 2018 
83102+15066
#Q3-Q4 2018- Q1-Q2 2019
278116 - 255655
#2018-2020
83102+15066+255655+472297+235267
# Out:
# 1061387

# %%
1-(1077424-1061387)/1061387
# Out:
# 0.984890525322055

# %%
((vel_ts*(mask_data)*(PIXEL_AREA)/0.764555*0.9071847*100).sum()*3.0/mask_data.sum()*mask_data_fill.sum(),
(mask_data*df_ts_A.Velocity.mean()*(PIXEL_AREA)/0.764555*0.9071847).sum()*3.0/mask_data.sum()*mask_data_fill.sum(),
(mask_data*df_ts_Q.Velocity.mean()*(PIXEL_AREA)/0.764555*0.9071847).sum()*3.0/mask_data.sum()*mask_data_fill.sum(),
(mask_data*df_ts_M.Velocity.mean()*(PIXEL_AREA)/0.764555*0.9071847).sum()*3.0/mask_data.sum()*mask_data_fill.sum())
# Out:
# (959193.8343465045, 1077424.9283765927, 1082302.3153584867, 1064018.5535723262)

# %%
fig = plt.figure(figsize=(12,7.5))
ax = fig.subplots()
plot_acf(df_ts_M.Displacement, zero=False, ax=ax, lags=12)
plot_pacf(df_ts_M.Displacement, zero=False, ax=ax, lags=12)
ax.set_title(None)
fig

# %%
fig = plt.figure(figsize=(width,height))
ax1 = fig.subplots()
sns.lineplot(data=df_ts_B.Displacement, marker='.', color='C7', ax=ax1);
sns.lineplot(data=df_ts_Q.Adj_Displacement, marker='o', color='C0', ax=ax1)
ax1.set_ylabel(r'Displacement [cm]')
# ax1.set_ylabel(None)
plt.legend(ax1.lines,["12-Day Displacement"]+["Quarterly Displacement"], loc='upper left')
sns.despine(right=True, trim=False)
fig.autofmt_xdate()
ax1.text(1.0,0.05,'Johannesburg',
        horizontalalignment='right',
        verticalalignment='bottom',
        transform=ax1.transAxes)
fig.tight_layout()
fig.savefig("pgf/jhb_displacement_velocity.pgf", backend='pgf', dpi=600)
fig

# %%
stringency = pd.read_csv("/data1/data/stringency_index.csv", index_col=1, parse_dates=True, )
stringency = stringency.T
stringency = stringency[2:] 
stringency.index = pd.DatetimeIndex(stringency.index)

# %%
STR = stringency['ZAF'].astype(float)
df_ts_Q['Stringency'] = STR.resample('Q') \
                           .mean()['2018-01-01':] 
df_ts_Q['Stringency'].fillna(0, inplace=True)

# %%
df_ts_M['Stringency'] = STR.resample('M') \
                           .mean()['2018-01-01':] 
df_ts_M['Stringency'].fillna(0, inplace=True)

# %%
fig = plt.figure(figsize=(width,height))
ax1 = sns.lineplot(data=stringency[['ZAF','BRA','TUR']].astype(float).loc[:'2020-12-31'])
ax1.set_ylabel(r'Stringency')
plt.legend(["South Africa","Brazil","Turkey"], loc='lower right')
sns.despine(right=True, trim=False);
fig.autofmt_xdate()
fig.tight_layout()
fig.savefig("pgf/stringency.pgf", backend='pgf', dpi=600)
fig

# %%
country = "South Africa Seasonal"
GDP = pd.read_csv("/data1/data/GDP.csv" )
GDP.index = pd.DatetimeIndex(GDP.Date)
GDP = GDP.resample('Q').max()
df_ts_Q.loc[:, "GDP"] = GDP[country]
df_ts_Q['Delta_GDP'] = GDP[country].diff()

GDP_M = (GDP[country]).resample('M').last()
GDP_M['2020-10-31'] = np.NaN
GDP_M['2020-11-30'] = np.NaN
GDP_M['2020-12-31'] = np.NaN

GDP_Q = GDP[country]

# %%
fig = plt.figure(figsize=(width,height))
ax1 = sns.lineplot(data=df_ts_Q.Velocity.loc[:'2020-09-30'], marker='o', color='C0');
# ax1.set_ylabel(r'Acceleration [cm/year\textsuperscript{2}]')
ax1.set_ylabel(None)
ax2 = plt.twinx()
sns.lineplot(data=df_ts_Q.GDP, ax=ax2, marker='.', color='C7')
ax2.set_ylabel(r'GDP [\textcurrency]')
# ax2.set_ylabel(None)
ax2.set_ylim(top=1350000)
plt.legend(ax1.lines+ax2.lines, ["Quarterly Velocity"]+["Quarterly GDP"], loc='upper left')
sns.despine(right=False, trim=False);
fig.autofmt_xdate()
fig.tight_layout()
fig.savefig("pgf/jhb_acceleration.pgf", backend='pgf', dpi=600)
fig

# %%
fig = plt.figure(figsize=(width,height))
ax1 = sns.lineplot(data=df_ts_Q.Displacement.loc[:'2020-09-30'], marker='o', color='C0')
# ax1.set_ylabel(r'Velocity [cm/year]')
ax1.set_ylabel(None)
# ax1.set_ylim(bottom=0)
ax2 = plt.twinx()
sns.lineplot(data=df_ts_Q.GDP, ax=ax2, marker='.', color='C7')
ax2.set_ylabel(r'GDP [\textcurrency]')
# ax2.set_ylim(top=1350000)
plt.legend(ax1.lines+ax2.lines, ["Quarterly Displacement"]+["Quarterly GDP"], loc='upper left')
sns.despine(right=False, trim=False);
fig.autofmt_xdate()
fig.tight_layout()
fig.savefig("pgf/jhb_velocity_GDP.pgf", backend='pgf', dpi=600)
fig

# %%
df_ts_M['GDP_naive']      = (df_ts_Q.GDP).resample('M').last()
df_ts_M['Delta_GDP_naive']= (df_ts_Q.Delta_GDP).resample('M').last()
df_ts_M.GDP_naive         =  df_ts_M.GDP_naive.bfill()
df_ts_M.Delta_GDP_naive   =  df_ts_M.Delta_GDP_naive.bfill()
df_ts_M['GDP'] = GDP_M.reset_index() \
                      .interpolate(method='spline', order=3) \
                      .set_index('Date') \
                      .shift(-1) #center on the middle of the quarter
df_ts_M['Delta_GDP'] = GDP_M.reset_index() \
                      .interpolate(method='spline', order=3) \
                      .set_index('Date') \
                      .shift(-1) \
                      .diff()
df_ts_M = df_ts_M[:'2020-09-30']
df_ts_M
# Out:
#             Displacement  Count  Days  Velocity  Adj_Displacement  \
# 2018-01-31      0.177849   25.0  31.0  1.696042          0.005737
# 2018-02-28      0.419627   22.0  28.0 -0.162098          0.014987
# 2018-03-31      0.627919   31.0  31.0  1.345727          0.020255
# 2018-04-30      0.679678   18.0  30.0 -0.322651          0.022656
# 2018-05-31      0.601695   31.0  31.0 -0.106310          0.019410
# 2018-06-30      0.576451   30.0  30.0  0.241218          0.019215
# 2018-07-31      0.718254   31.0  31.0  0.694277          0.023169
# 2018-08-31      0.776792   31.0  31.0 -0.141016          0.025058
# 2018-09-30      0.572226   30.0  30.0 -1.300414          0.019074
# 2018-10-31      0.870752   31.0  31.0  1.513563          0.028089
# 2018-11-30      0.854852   30.0  30.0  0.328491          0.028495
# 2018-12-31      1.022665   31.0  31.0  0.537434          0.032989
# 2019-01-31      0.991639   31.0  31.0 -0.473142          0.031988
# 2019-02-28      0.977215   28.0  28.0  1.012890          0.034901
# 2019-03-31      1.273599   19.0  31.0  1.676779          0.041084
# 2019-04-30      1.291121   18.0  30.0 -1.056886          0.043037
# 2019-05-31      1.321402   31.0  31.0  0.595728          0.042626
# 2019-06-30      1.406925   30.0  30.0  0.382730          0.046897
# 2019-07-31      1.539173   31.0  31.0  0.499396          0.049651
# 2019-08-31      1.607975   31.0  31.0  0.167719          0.051870
# 2019-09-30      1.633610   30.0  30.0  0.532799          0.054454
# 2019-10-31      1.756073   31.0  31.0  0.665331          0.056648
# 2019-11-30      1.860246   18.0  30.0  0.527430          0.062008
# 2019-12-31      1.951526   31.0  31.0 -0.627279          0.062952
# 2020-01-31      1.869598   31.0  31.0  0.912745          0.060310
# 2020-02-29      1.730014   29.0  29.0 -1.320886          0.059656
# 2020-03-31      2.300820   31.0  31.0  2.690850          0.074220
# 2020-04-30      2.260892   30.0  30.0  0.171222          0.075363
# 2020-05-31      2.410136   31.0  31.0  0.198853          0.077746
# 2020-06-30      2.467466   30.0  30.0  0.573368          0.082249
# 2020-07-31      2.616448   31.0  31.0  0.302522          0.084402
# 2020-08-31      2.727269   31.0  31.0  0.627569          0.087976
# 2020-09-30      2.652290   30.0  30.0 -0.185609          0.088410
#
#             Acceleration  Stringency  GDP_naive  Delta_GDP_naive  \
# 2018-01-31      1.752616    0.000000  1184810.6         -15668.4
# 2018-02-28     -1.858140    0.000000  1184810.6         -15668.4
# 2018-03-31      1.507825    0.000000  1184810.6         -15668.4
# 2018-04-30     -1.668378    0.000000  1207223.6          22413.0
# 2018-05-31      0.216341    0.000000  1207223.6          22413.0
# 2018-06-30      0.347528    0.000000  1207223.6          22413.0
# 2018-07-31      0.453060    0.000000  1226162.8          18939.2
# 2018-08-31     -0.835293    0.000000  1226162.8          18939.2
# 2018-09-30     -1.159398    0.000000  1226162.8          18939.2
# 2018-10-31      2.813977    0.000000  1231225.4           5062.6
# 2018-11-30     -1.185073    0.000000  1231225.4           5062.6
# 2018-12-31      0.208944    0.000000  1231225.4           5062.6
# 2019-01-31     -1.010576    0.000000  1237222.0           5996.6
# 2019-02-28      1.486032    0.000000  1237222.0           5996.6
# 2019-03-31      0.663889    0.000000  1237222.0           5996.6
# 2019-04-30     -2.733665    0.000000  1260543.6          23321.6
# 2019-05-31      1.652614    0.000000  1260543.6          23321.6
# 2019-06-30     -0.212998    0.000000  1260543.6          23321.6
# 2019-07-31      0.116666    0.000000  1278992.8          18449.2
# 2019-08-31     -0.331678    0.000000  1278992.8          18449.2
# 2019-09-30      0.365080    0.000000  1278992.8          18449.2
# 2019-10-31      0.132532    0.000000  1281830.4           2837.6
# 2019-11-30     -0.137901    0.000000  1281830.4           2837.6
# 2019-12-31     -1.154708    0.000000  1281830.4           2837.6
# 2020-01-31      1.540024    0.807097  1295758.5          13928.1
# 2020-02-29     -2.233632    2.780000  1295758.5          13928.1
# 2020-03-31      4.011736   39.338065  1295758.5          13928.1
# 2020-04-30     -2.519627   87.960000  1084061.1        -211697.4
# 2020-05-31      0.027630   84.260000  1084061.1        -211697.4
# 2020-06-30      0.374516   77.715667  1084061.1        -211697.4
# 2020-07-31     -0.270846   79.243548  1263065.9         179004.8
# 2020-08-31      0.325046   77.869677  1263065.9         179004.8
# 2020-09-30     -0.813178   62.034000  1263065.9         179004.8
#
#                      GDP      Delta_GDP
# 2018-01-31  1.189141e+06   -7353.421144
# 2018-02-28  1.184811e+06   -4330.278510
# 2018-03-31  1.188171e+06    3360.236990
# 2018-04-30  1.196968e+06    8797.129733
# 2018-05-31  1.207224e+06   10255.633277
# 2018-06-30  1.215668e+06    8444.510240
# 2018-07-31  1.221884e+06    6215.808724
# 2018-08-31  1.226163e+06    4278.881036
# 2018-09-30  1.228832e+06    2669.510383
# 2018-10-31  1.230354e+06    1521.872835
# 2018-11-30  1.231225e+06     871.216782
# 2018-12-31  1.232028e+06     802.915747
# 2019-01-31  1.233690e+06    1661.336707
# 2019-02-28  1.237222e+06    3532.347546
# 2019-03-31  1.243318e+06    6095.846989
# 2019-04-30  1.251393e+06    8075.488403
# 2019-05-31  1.260544e+06    9150.264608
# 2019-06-30  1.269629e+06    9085.834868
# 2019-07-31  1.276555e+06    6925.801747
# 2019-08-31  1.278993e+06    2437.563384
# 2019-09-30  1.276301e+06   -2691.667699
# 2019-10-31  1.274634e+06   -1667.104089
# 2019-11-30  1.281830e+06    7196.371788
# 2019-12-31  1.300583e+06   18752.706889
# 2020-01-31  1.312929e+06   12345.610224
# 2020-02-29  1.295758e+06  -17170.217113
# 2020-03-31  1.235138e+06  -60620.318954
# 2020-04-30  1.153902e+06  -81235.962503
# 2020-05-31  1.084061e+06  -69841.118543
# 2020-06-30  1.057633e+06  -26427.691530
# 2020-07-31  1.106630e+06   48996.212390
# 2020-08-31  1.263066e+06  156436.279141
# 2020-09-30  1.558956e+06  295890.030391

# %%
dates_prior = slice('2018-01-01','2019-12-31')
dates_full = slice('2018-01-01','2020-08-31')

# %%
fig = plt.figure(figsize=(width,height))
ax1 = sns.lineplot(data=df_ts_M.Displacement.loc[dates_full], marker='o', color='C0')
# ax1.set_ylabel(r'Velocity [cm/year]')
ax1.set_ylabel(None)
ax2 = plt.twinx()
# sns.lineplot(data=df_ts_M.GDP_naive.loc[dates_full], ax=ax2, marker='.', color='C1')
sns.lineplot(data=df_ts_M.GDP.loc[dates_full], ax=ax2, marker='.', markersize=4, color='C7')
ax2.set_ylabel(r'GDP [\textcurrency]')
# ax2.set_ylim(top=1350000)
plt.legend(ax1.lines+ax2.lines, ["Monthly Displacement"]+["Monthly GDP"], loc='upper left')
sns.despine(right=False, trim=False);
fig.autofmt_xdate()
fig.tight_layout()
fig.savefig("pgf/jhb_velocity_GDP_monthly.pgf", backend='pgf', dpi=600)
fig

# %% [markdown]
# https://columbiaeconomics.com/2010/01/20/how-economists-convert-quarterly-data-into-monthly-cubic-spline-interpolation/comment-page-1/

# %%
import statsmodels.api as sm
X_var = ['GDP']
X = df_ts_M.loc[dates_prior, X_var]
y = df_ts_M.Displacement[dates_prior]
X = sm.add_constant(X)
# X['trend'] = range(1,len(X)+1)
# Note the difference in argument order
model = sm.OLS(y, X).fit(cov_type='HAC',cov_kwds={'maxlags':12})
# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Displacement   R-squared:                       0.915
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     303.1
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           2.37e-14
# Time:                        19:44:54   Log-Likelihood:                 13.047
# No. Observations:                  24   AIC:                            -22.09
# Df Residuals:                      22   BIC:                            -19.74
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -16.6111      1.012    -16.415      0.000     -18.594     -14.628
# GDP         1.426e-05   8.19e-07     17.410      0.000    1.27e-05    1.59e-05
# ==============================================================================
# Omnibus:                        0.406   Durbin-Watson:                   1.034
# Prob(Omnibus):                  0.816   Jarque-Bera (JB):                0.004
# Skew:                          -0.010   Prob(JB):                        0.998
# Kurtosis:                       3.060   Cond. No.                     4.76e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 12 lags and without small sample correction
# [2] The condition number is large, 4.76e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels.api as sm
X_var = ['GDP']
X = df_ts_M.loc[dates_full, X_var]
y = df_ts_M.Displacement[dates_full]
X = sm.add_constant(X)
# X['trend'] = range(1,len(X)+1)
# Note the difference in argument order
model = sm.OLS(y, X).fit(cov_type='HAC',cov_kwds={'maxlags':12})
# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Displacement   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                 -0.018
# Method:                 Least Squares   F-statistic:                    0.2177
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):              0.644
# Time:                        19:44:54   Log-Likelihood:                -33.616
# No. Observations:                  32   AIC:                             71.23
# Df Residuals:                      30   BIC:                             74.16
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.1195      3.976      0.785      0.433      -4.674      10.913
# GDP        -1.425e-06   3.05e-06     -0.467      0.641   -7.41e-06    4.56e-06
# ==============================================================================
# Omnibus:                        4.154   Durbin-Watson:                   0.060
# Prob(Omnibus):                  0.125   Jarque-Bera (JB):                1.688
# Skew:                           0.118   Prob(JB):                        0.430
# Kurtosis:                       1.900   Cond. No.                     2.56e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 12 lags and without small sample correction
# [2] The condition number is large, 2.56e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels.api as sm
X_var = ['GDP','Stringency']
X = df_ts_M.loc[dates_full, X_var]
y = df_ts_M.Displacement[dates_full]
X = sm.add_constant(X)
# X['trend'] = range(0,len(X))
# Note the difference in argument order
model = sm.OLS(y, X).fit(cov_type='HAC',cov_kwds={'maxlags':12})
# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Displacement   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.791
# Method:                 Least Squares   F-statistic:                     51.44
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           2.90e-10
# Time:                        19:44:54   Log-Likelihood:                -7.7477
# No. Observations:                  32   AIC:                             21.50
# Df Residuals:                      29   BIC:                             25.89
# Df Model:                           2
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -8.8677      3.468     -2.557      0.011     -15.664      -2.071
# GDP         8.029e-06   2.76e-06      2.906      0.004    2.61e-06    1.34e-05
# Stringency     0.0279      0.004      6.579      0.000       0.020       0.036
# ==============================================================================
# Omnibus:                        0.592   Durbin-Watson:                   1.050
# Prob(Omnibus):                  0.744   Jarque-Bera (JB):                0.400
# Skew:                          -0.266   Prob(JB):                        0.819
# Kurtosis:                       2.865   Cond. No.                     3.49e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 12 lags and without small sample correction
# [2] The condition number is large, 3.49e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels.api as sm
X_var = ['GDP','Stringency']
dates = slice('2018-03-31','2020-09-30')
X = df_ts_Q.loc[dates, X_var]
y = df_ts_Q.Displacement[dates]
X = sm.add_constant(X)
# X['trend'] = range(1,len(X)+1)
# Note the difference in argument order
model = sm.OLS(y, X).fit(cov_type='HAC',cov_kwds={'maxlags':4})
X_all = df_ts_Q.loc[dates, X_var]
X_all.Stringency = 0.0
X_all = sm.add_constant(X_all)
# X_all['trend'] = range(1,len(X)+1)
predictions = model.predict(X_all) # make the predictions by the model
# Print out the statistics
model.summary()
# Out:
# /home/tvanzyl/anaconda3/envs/mintpy/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Displacement   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     44.93
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           4.47e-05
# Time:                        19:44:54   Log-Likelihood:                -13.351
# No. Observations:                  11   AIC:                             32.70
# Df Residuals:                       8   BIC:                             33.90
# Df Model:                           2
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -23.9661      8.458     -2.834      0.005     -40.543      -7.390
# GDP         2.194e-05   6.69e-06      3.279      0.001    8.83e-06    3.51e-05
# Stringency     0.0753      0.010      7.356      0.000       0.055       0.095
# ==============================================================================
# Omnibus:                        0.785   Durbin-Watson:                   1.123
# Prob(Omnibus):                  0.675   Jarque-Bera (JB):                0.613
# Skew:                           0.149   Prob(JB):                        0.736
# Kurtosis:                       1.883   Cond. No.                     3.11e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 4 lags and without small sample correction
# [2] The condition number is large, 3.11e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_ts_Q["Prediction"] = predictions
df_ts_Q["Residual_Displacement"] = (df_ts_Q.Displacement-df_ts_Q.Prediction)

# %%
df_ts_Q.loc['20180101':'20191231',['Velocity','Displacement','Acceleration','GDP','Delta_GDP','Residual_Displacement']].corr()
# Out:
#                        Velocity  Displacement  Acceleration       GDP  \
# Velocity               1.000000     -0.179336      0.799746 -0.293103
# Displacement          -0.179336      1.000000     -0.125436  0.974691
# Acceleration           0.799746     -0.125436      1.000000 -0.150378
# GDP                   -0.293103      0.974691     -0.150378  1.000000
# Delta_GDP             -0.806411      0.237235     -0.679768  0.394980
# Residual_Displacement -0.065488      0.978184     -0.096573  0.906985
#
#                        Delta_GDP  Residual_Displacement
# Velocity               -0.806411              -0.065488
# Displacement            0.237235               0.978184
# Acceleration           -0.679768              -0.096573
# GDP                     0.394980               0.906985
# Delta_GDP               1.000000               0.079895
# Residual_Displacement   0.079895               1.000000

# %%
df_ts_Q.loc['20180101':'20200930',['Velocity','Displacement','Acceleration','GDP','Delta_GDP','Residual_Displacement','Stringency']].corr()
# Out:
#                        Velocity  Displacement  Acceleration       GDP  \
# Velocity               1.000000     -0.061500      0.804406 -0.000684
# Displacement          -0.061500      1.000000     -0.109633  0.066868
# Acceleration           0.804406     -0.109633      1.000000  0.216569
# GDP                   -0.000684      0.066868      0.216569  1.000000
# Delta_GDP             -0.108466      0.015193      0.095703  0.749801
# Residual_Displacement -0.054399      0.855612     -0.209958 -0.459247
# Stringency            -0.065475      0.771818     -0.183331 -0.488313
#
#                        Delta_GDP  Residual_Displacement  Stringency
# Velocity               -0.108466              -0.054399   -0.065475
# Displacement            0.015193               0.855612    0.771818
# Acceleration            0.095703              -0.209958   -0.183331
# GDP                     0.749801              -0.459247   -0.488313
# Delta_GDP               1.000000              -0.375455   -0.190734
# Residual_Displacement  -0.375455               1.000000    0.940477
# Stringency             -0.190734               0.940477    1.000000

# %%
fig = plt.figure(figsize=(width,height))
ax = sns.lineplot(data=df_ts_Q.Prediction, marker='.', color='C7')
sns.lineplot(data=df_ts_Q.Displacement.loc[dates], marker='o', color='C0', ax=ax)
ax.set_ylabel(r'Displacement [cm]')
plt.legend(["Displacement Scenario","Actual Displacement"], loc='upper left')
sns.despine(trim=False);
fig.autofmt_xdate()
fig.tight_layout()
fig.savefig("pgf/jhb_scenario_velocity.pgf", backend='pgf', dpi=600)
fig

# %%
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA
model = AutoReg(df_ts_M.loc[:'20200731','Displacement'], lags=1, trend='t', exog=df_ts_M.loc[:'20200731',['Stringency','GDP']])
# model = ARIMA(df_ts_M.loc[:'20200630','Velocity'], order=(1,0,0), exog=df_ts_M.loc[:'20200630',['Stringency','GDP']])
res = model.fit()
print(res.summary())
pred_res = res.get_prediction(start='20180131', end='20200930', exog_oos=df_ts_M.loc['20200830':'20200930',['Stringency','GDP']])
# pred_res = res.get_prediction(start='20180131', end='20200930', exog=df_ts_M.loc['20200731':'20200930',['Stringency','GDP']])
P = pred_res.conf_int()[dates]
P['mean'] = pred_res.predicted_mean[dates]
PP = P.unstack().rename('Displacement').to_frame().reset_index()
# Out:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:           Displacement   No. Observations:                   31
# Model:                   AutoReg-X(1)   Log Likelihood                  24.796
# Method:               Conditional MLE   S.D. of innovations              0.106
# Date:                Tue, 01 Jun 2021   AIC                             -4.158
# Time:                        19:44:54   BIC                             -3.924
# Sample:                    02-28-2018   HQIC                            -4.083
#                          - 07-31-2020
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# trend               0.0578      0.012      4.912      0.000       0.035       0.081
# Displacement.L1     0.0997      0.173      0.575      0.565      -0.240       0.439
# Stringency          0.0037      0.001      3.455      0.001       0.002       0.006
# GDP              1.951e-07   4.56e-08      4.279      0.000    1.06e-07    2.84e-07
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           10.0302           +0.0000j           10.0302            0.0000
# -----------------------------------------------------------------------------
# /home/tvanzyl/anaconda3/envs/mintpy/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(

# %%
fig = plt.figure(figsize=(width,height))
ax = sns.lineplot(data=PP, x='level_1', y='Displacement',  marker='.', color='C7')
ax.set_xlabel(None)
sns.lineplot(data=df_ts_M.Displacement.loc[dates], marker='o', markersize=3, color='C0', ax=ax)
ax.set_ylabel(r'Displacement [cm]')
plt.legend(["Predicted Displacement","Actual Displacement"], loc='upper left')
sns.despine(trim=False);
fig.autofmt_xdate()
fig.tight_layout()
fig.savefig("pgf/jhb_predicted_velocity.pgf", backend='pgf', dpi=600)
fig
