# %%
dinsar_path = "/data1/data/sar_jhb_dumps/dinsar"
snaphu_path = "/data1/data/sar_jhb_dumps/snaphu"
unwraped_path = "/data1/data/sar_jhb_dumps/unwraped"
tc_path = "/data1/data/sar_jhb_dumps/tc"
# !mkdir $snaphu_path
# !mkdir $unwraped_path
# !mkdir $tc_path
# Out:
# mkdir: cannot create directory ‘/data1/data/sar_jhb_dumps/snaphu’: File exists
# mkdir: cannot create directory ‘/data1/data/sar_jhb_dumps/unwraped’: File exists
# mkdir: cannot create directory ‘/data1/data/sar_jhb_dumps/tc’: File exists

# %%
b = !ls $snaphu_path

# %%
b
# Out:
# ['20171102_20180101',
#  '20171114_20180101',
#  '20171114_20180113',
#  '20171126_20180101',
#  '20171126_20180113',
#  '20171126_20180125',
#  '20171208_20180101',
#  '20171208_20180113',
#  '20171208_20180125',
#  '20171208_20180206',
#  '20171220_20180101',
#  '20171220_20180113',
#  '20171220_20180125',
#  '20171220_20180206',
#  '20171220_20180218',
#  '20180101_20180113',
#  '20180101_20180125',
#  '20180101_20180206',
#  '20180101_20180218',
#  '20180101_20180302',
#  '20180113_20180125',
#  '20180113_20180206',
#  '20180113_20180218',
#  '20180113_20180302',
#  '20180113_20180314',
#  '20180125_20180206',
#  '20180125_20180218',
#  '20180125_20180302',
#  '20180125_20180314',
#  '20180206_20180218',
#  '20180206_20180302']

# %%
for i in range(len(b)):
    source_name = b[i]
    source_path = "{}/{}.dim".format(dinsar_path, source_name)
    # !gpt SnaphuExport -Ssource=$source_path -PtargetFolder=$snaphu_path
    # %cd $snaphu_path/$source_name
    cmd_grep = !cat $snaphu_path/$source_name/snaphu.conf | grep "snaphu -f"
    cmd = cmd_grep[0].split("#")[1].strip()
    # !$cmd
    break
# Out:
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# Executing operator...
# 20%....30%....41%....52%....62%....72%....82%....92%.... done.
# -- org.jblas INFO Deleting /tmp/jblas315010137063333072/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas315010137063333072/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas315010137063333072/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas315010137063333072/libgfortran-4.so
# ...

# %%
# !gpt SnaphuImport -t "/data1/data/sar_jhb_dumps/unwraped/20171102_20180101.dim" "/data1/data/sar_jhb_dumps/dinsar/20171102_20180101.dim" "/data1/data/sar_jhb_dumps/snaphu/20171102_20180101/UnwPhase_ifg_VV_02Nov2017_01Jan2018.snaphu.hdr"
# Out:
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# Executing operator...
# 20%....30%.....42%....52%....62%.....74%....84%.....96%. done.
# INFO: org.esa.snap.core.gpf.common.WriteOp: Start writing product 20171102_20180101 to /data1/data/sar_jhb_dumps/unwraped/20171102_20180101.dim
# Writing...
# ...11%...23%21%....33%....43%....53%....63%....73%....83%....93%... done.
# ...

# %%
for i in range(len(b)):
    source_name = b[i]
    source_path1 = "{}/{}.dim".format(dinsar_path, source_name)    
    c = !ls $snaphu_path/$source_name/UnwPhase*.hdr
    source_path2 = c[0]
    print(unwraped_path, source_name, source_path1, source_path2)
    # !gpt SnaphuImport -t {"\""+unwraped_path+"/"+source_name+".dim"+"\""} {"\""+source_path1+"\""} {"\""+source_path2+"\""}
# Out:
# /data1/data/sar_jhb_dumps/unwraped/ 20171102_20180101 /data1/data/sar_jhb_dumps/dinsar/20171102_20180101.dim /data1/data/sar_jhb_dumps/snaphu/20171102_20180101/UnwPhase_ifg_VV_02Nov2017_01Jan2018.snaphu.hdr
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# Executing operator...
# 20%....30%.....42%....52%....62%.....74%....84%86%.....98% done.
# ...

# %%
for i in range(len(b)):
    source_name = b[i]
    source_path = "{}/{}.dim".format(unwraped_path, source_name)    
    print(tc_path, source_name, source_path)
    # !gpt Terrain-Correction -t {"\""+tc_path+"/"+source_name+".dim"+"\""} -PdemName="SRTM 1Sec HGT" {"\""+source_path+"\""}
# !gpt Terrain-Correction -t "/data1/data/sar_jhb_dumps/tc/20171102_20180101.dim" -PdemName='SRTM 1Sec HGT' "/data1/data/sar_jhb_dumps/unwraped/20171102_20180101.dim"
# Out:
# /data1/data/sar_jhb_dumps/tc 20171102_20180101 /data1/data/sar_jhb_dumps/unwraped/20171102_20180101.dim
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# Executing operator...
# 20%....30%....40%....50%.....60%....70%70%.....82%.....94%.. done.
# INFO: org.esa.snap.core.gpf.common.WriteOp: Start writing product 20171102_20180101_TC to /data1/data/sar_jhb_dumps/tc/20171102_20180101.dim
# Writing...
# ...

# %%
# !gpt -h
# Out:
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Usage:
#   gpt <op>|<graph-file> [options] [<source-file-1> <source-file-2> ...]
#
# Description:
#   This tool is used to execute SNAP raster data operators in batch-mode. The
#   operators can be used stand-alone or combined as a directed acyclic graph
#   (DAG). Processing graphs are represented using XML. More info about
#   processing graphs, the operator API, and the graph XML format can be found
#   in the SNAP documentation.
#
# Arguments:
# ...
