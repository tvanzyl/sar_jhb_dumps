# %%
data_dir = "/data1/data/sar_rio_dumps/"
dinsar_dir = "/data1/data/sar_rio_dumps/dinsar/"
overlap = 5
# !mkdir $dinsar_dir

# %%
a = !ls $data_dir*.zip
a.sort()
print(a[0], a[1])
# Out:
# /data1/data/sar_rio_dumps/S1B_IW_SLC__1SDV_20171111T082129_20171111T082156_008231_00E8E9_5F93.zip /data1/data/sar_rio_dumps/S1B_IW_SLC__1SDV_20171123T082128_20171123T082155_008406_00EE34_21E0.zip

# %%
for i in range(overlap,overlap+31):
    for j in range(overlap, 0, -1):
        print(a[i-j][43:51],a[i][43:51])
        master = a[i-j]
        slave = a[i]
        target_name = "{}_{}".format(a[i-j][43:51],a[i][43:51])
        target = "{}{}_{}.dim".format(dinsar_dir,a[i-j][43:51],a[i][43:51])
        c = !ls $dinsar_dir | grep $target_name
        print(c)
        if len(c) == 0:
            # !gpt graph/TOPSAR\ Coreg\ Interferogram\ VV\ IW\ 2_3\ B\ 8_9.xml -Pmaster=$master -Pslave=$slave -Ptarget=$target -c 64G -q 12
# Out:
# 20171111 20180110
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://aux.sentinel1.eo.esa.int/POEORB/2017/12/01/S1A_OPER_AUX_POEORB_OPOD_20171201T121227_V20171110T225942_20171112T005942.EOF
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://step.esa.int/auxdata/orbits/Sentinel-1/POEORB/S1B/2017/11/S1B_OPER_AUX_POEORB_OPOD_20171201T110954_V20171110T225942_20171112T005942.EOF.zip
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://aux.sentinel1.eo.esa.int/POEORB/2018/01/30/S1A_OPER_AUX_POEORB_OPOD_20180130T121337_V20180109T225942_20180111T005942.EOF
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://step.esa.int/auxdata/orbits/Sentinel-1/POEORB/S1B/2018/01/S1B_OPER_AUX_POEORB_OPOD_20180130T111118_V20180109T225942_20180111T005942.EOF.zip
# ...11%...22%...33%...44%.INFO: org.esa.snap.core.dataop.dem.ElevationFile: http retrieving http://step.esa.int/auxdata/dem/SRTMGL1/S23W044.SRTMGL1.hgt.zip
# INFO: org.esa.snap.core.dataop.dem.ElevationFile: http retrieving http://step.esa.int/auxdata/dem/SRTMGL1/S23W045.SRTMGL1.hgt.zip
# INFO: org.esa.snap.core.dataop.dem.ElevationFile: http retrieving http://step.esa.int/auxdata/dem/SRTMGL1/S22W044.SRTMGL1.hgt.zip
# INFO: org.esa.snap.core.dataop.dem.ElevationFile: http retrieving http://step.esa.int/auxdata/dem/SRTMGL1/S22W043.SRTMGL1.hgt.zip
# INFO: org.esa.snap.core.dataop.dem.ElevationFile: http retrieving http://step.esa.int/auxdata/dem/SRTMGL1/S22W045.SRTMGL1.hgt.zip
# SEVERE: org.esa.snap.core.dataop.dem.ElevationFile: error in opening zip file
# INFO: org.esa.snap.core.dataop.dem.ElevationFile: http retrieving http://step.esa.int/auxdata/dem/SRTMGL1/S22W045.SRTMGL1.hgt.zip
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# WARNING: org.esa.snap.dem.dataio.srtm1_hgt.SRTMHGTReader: Unable to read SRTM HGT: invalid stored block lengths
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW2_range_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW3_range_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Estimating azimuth offset for blocks in overlap: 1/1
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Estimating azimuth offset for blocks in overlap: 1/1
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW3_azimuth_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW2_azimuth_shifts.json
# INFO: org.esa.snap.core.dataop.dem.ElevationFile: http retrieving http://step.esa.int/auxdata/dem/SRTMGL1/S24W044.SRTMGL1.hgt.zip
# ..55%...66%...77%...90% done.
# -- org.jblas INFO Deleting /tmp/jblas7419612310181484233/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas7419612310181484233/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas7419612310181484233/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas7419612310181484233/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas7419612310181484233
# 20171123 20180110
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://aux.sentinel1.eo.esa.int/POEORB/2017/12/13/S1A_OPER_AUX_POEORB_OPOD_20171213T121421_V20171122T225942_20171124T005942.EOF
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://step.esa.int/auxdata/orbits/Sentinel-1/POEORB/S1B/2017/11/S1B_OPER_AUX_POEORB_OPOD_20171213T111324_V20171122T225942_20171124T005942.EOF.zip
# WARNING: org.jlinda.core.Baseline: Max. error bperp modeling at 3D datapoints: 2.22861677410347m
# WARNING: org.jlinda.core.Baseline: Max. error bperp modeling at 3D datapoints: 2.2286838325239797m
# ....11%....21%....31%.INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW3_range_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW2_range_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Estimating azimuth offset for blocks in overlap: 1/1
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Estimating azimuth offset for blocks in overlap: 1/1
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW3_azimuth_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW2_azimuth_shifts.json
# ...42%....52%....62%....72%....82%... done.
# -- org.jblas INFO Deleting /tmp/jblas6320272311842287446/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas6320272311842287446/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas6320272311842287446/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas6320272311842287446/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas6320272311842287446
# 20171205 20180110
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://aux.sentinel1.eo.esa.int/POEORB/2017/12/25/S1A_OPER_AUX_POEORB_OPOD_20171225T121139_V20171204T225942_20171206T005942.EOF
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://step.esa.int/auxdata/orbits/Sentinel-1/POEORB/S1B/2017/12/S1B_OPER_AUX_POEORB_OPOD_20171225T110951_V20171204T225942_20171206T005942.EOF.zip
# ....11%....21%....31%.INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW2_range_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW3_range_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Estimating azimuth offset for blocks in overlap: 1/1
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Estimating azimuth offset for blocks in overlap: 1/1
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW3_azimuth_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW2_azimuth_shifts.json
# ...42%....52%....62%....72%....82%... done.
# -- org.jblas INFO Deleting /tmp/jblas3232140514464956076/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas3232140514464956076/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas3232140514464956076/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas3232140514464956076/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas3232140514464956076
# 20171217 20180110
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://aux.sentinel1.eo.esa.int/POEORB/2018/01/06/S1A_OPER_AUX_POEORB_OPOD_20180106T121204_V20171216T225942_20171218T005942.EOF
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://step.esa.int/auxdata/orbits/Sentinel-1/POEORB/S1B/2017/12/S1B_OPER_AUX_POEORB_OPOD_20180106T110810_V20171216T225942_20171218T005942.EOF.zip
# ...11%...22%...33%...44%.INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW2_range_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW3_range_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Estimating azimuth offset for blocks in overlap: 1/1
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Estimating azimuth offset for blocks in overlap: 1/1
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW3_azimuth_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW2_azimuth_shifts.json
# ..55%...66%...77%...90% done.
# -- org.jblas INFO Deleting /tmp/jblas4184722523348624621/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas4184722523348624621/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas4184722523348624621/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas4184722523348624621/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas4184722523348624621
# 20171229 20180110
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://aux.sentinel1.eo.esa.int/POEORB/2018/01/18/S1A_OPER_AUX_POEORB_OPOD_20180118T121644_V20171228T225942_20171230T005942.EOF
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://step.esa.int/auxdata/orbits/Sentinel-1/POEORB/S1B/2017/12/S1B_OPER_AUX_POEORB_OPOD_20180118T110837_V20171228T225942_20171230T005942.EOF.zip
# ....11%....21%....31%.INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW3_range_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW2_range_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Estimating azimuth offset for blocks in overlap: 1/1
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Estimating azimuth offset for blocks in overlap: 1/1
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW3_azimuth_shifts.json
# INFO: org.esa.s1tbx.sentinel1.gpf.SpectralDiversityOp: Shifts written to file: /home/terencevz/.snap/var/log/IW2_azimuth_shifts.json
# ...42%....52%....62%....72%....82%... done.
# -- org.jblas INFO Deleting /tmp/jblas7457731083227923075/libquadmath-0.so
# -- org.jblas INFO Deleting /tmp/jblas7457731083227923075/libgfortran-4.so
# -- org.jblas INFO Deleting /tmp/jblas7457731083227923075/libjblas_arch_flavor.so
# -- org.jblas INFO Deleting /tmp/jblas7457731083227923075/libjblas.so
# -- org.jblas INFO Deleting /tmp/jblas7457731083227923075
# 20171123 20180122
# []
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: GDAL not found on system. Internal GDAL 3.0.0 from distribution will be used. (f1)
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# Executing processing graph
# INFO: org.hsqldb.persist.Logger: dataFileCache open start
# INFO: org.esa.snap.engine_utilities.download.DownloadableContentImpl: http retrieving http://aux.sentinel1.eo.esa.int/POEORB/2018